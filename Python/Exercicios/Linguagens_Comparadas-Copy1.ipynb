# %% [markdown]
# ### Exercícios comparativos de linguagens:

# %% [markdown]
# 1) Dado os seguintes algoritmos em linguagens específicas, crie um algoritmo equivalente em linguagem Python
#
# https://rosettacode.org/wiki/Sorting_algorithms/Quicksort

# %% [raw]
# # R
#
# qsort <- function(v) {
#   if (length(v) > 1)
#   {
#     pivot <- (min(v) + max(v))/2.0  # Could also use pivot <- median(v)
#     c(qsort(v[v < pivot]), v[v == pivot], qsort(v[v > pivot]))
#   } else v
# }
#
# N <- 100
# vs <- runif(N)
# system.time(u <- qsort(vs))
# print(u)

# %% [raw]
# # Common Lisp
#
# (defun quicksort (list &aux (pivot (car list)) )
#   (if (cdr list)
#       (nconc (quicksort (remove-if-not #'(lambda (x) (< x pivot)) list))
#              (remove-if-not #'(lambda (x) (= x pivot)) list)
#              (quicksort (remove-if-not #'(lambda (x) (> x pivot)) list)))
#       list))

# %%
#C

#include <stdio.h>
void quicksort(int *A, int len);
 
int main (void) {
  int a[] = {4, 65, 2, -31, 0, 99, 2, 83, 782, 1};
  int n = sizeof a / sizeof a[0];
  int i;
  for (i = 0; i < n; i++) {
    printf("%d ", a[i]);
  }
  printf("\n");
  quicksort(a, n);
  for (i = 0; i < n; i++) {
    printf("%d ", a[i]);
  }
  printf("\n");
  return 0;
}

# %% [markdown]
# 2) Escreva um código em R para receber um vetor de inteiros e retornar um vetor com os inteiros pares dentre os inteiros da primeira lista

# %%
v <- c(1,2,24,0,13)
v[v%%2==0]

# %% [markdown]
# 3) Escreva um código em Common Lisp para receber um vetor de inteiros e retornar um vetor com os inteiros pares dentre os inteiros da primeira lista

# %% [markdown]
# 4) Faça um programa em Python equivalente ao seguinte programa em R:

# %%
converte <- function (x) 
{
  romans <- c("M", "CM", "D", "CD", "C", "XC", "L", "XL", "X", 
              "IX", "V", "IV", "I")
  numbers <- c(1000L, 900L, 500L, 400L, 100L, 90L, 50L, 40L, 
               10L, 9L, 5L, 4L, 1L)
  out <- integer(length(x))
  ind <- is.na(x)
  out[ind] <- NA
  if (any(!ind)) {
    y <- toupper(x[!ind])
    y <- gsub("CM", "DCCCC", y)
    y <- gsub("CD", "CCCC", y)
    y <- gsub("XC", "LXXXX", y)
    y <- gsub("XL", "XXXX", y)
    y <- gsub("IX", "VIIII", y)
    y <- gsub("IV", "IIII", y)
    ok <- grepl("^M{,3}D?C{,4}L?X{,4}V?I{,4}$", y)
    if (any(!ok)) {
      warning(sprintf(ngettext(sum(!ok), "invalid roman numeral: %s", 
                               "invalid roman numerals: %s"), paste(x[!ind][!ok], 
                                                                    collapse = " ")), domain = NA)
      out[!ind][!ok] <- NA
    }
    if (any(ok)) 
      out[!ind][ok] <- sapply(strsplit(y[ok], ""), function(z) as.integer(sum(numbers[match(z, 
                                                                                            romans)])))
  }
  out
}

# %%
def convert(x):
    romans = ["M", "CM", "D", "CD", "C", "XC", "L", "XL", "X", "IX", "V", "IV", "I"]
    numbers = [1000, 900, 500, 400, 100, 90, 50, 40, 10, 9, 5, 4, 1]
    out = len(x)
    x=x.replace('CM', 'DCCC')
    x=x.replace('CD', 'CCCC')
    x=x.replace('XC', 'LXXXX')
    x=x.replace('XL', 'XXXX')
    x=x.replace('IX', 'VIIII')
    x=x.replace('IV', 'IIII')
    C=[]
    for c in x:
        C.append(c)
    valor = 0
    for item in C:
        i = romans.index(item)
        valor += numbers[i]
    return(valor)

# %%
convert('MCCCIX')
# Out:
# ['M', 'C', 'C', 'C', 'V', 'I', 'I', 'I', 'I']
# 1309

# %% [markdown]
# 5) Faça um programa em Python equivalente ao seguinte programa em C:

# %%
/* A function that prints given number in words */
void convert_to_words(char *num)
{
    int len = strlen(num);  // Get number of digits in given number
 
    /* Base cases */
    if (len == 0) {
        fprintf(stderr, "empty string\n");
        return;
    }
    if (len > 4) {
        fprintf(stderr, "Length more than 4 is not supported\n");
        return;
    }
 
    /* The first string is not used, it is to make array indexing simple */
    char *single_digits[] = { "zero", "one", "two", "three", "four",
                              "five", "six", "seven", "eight", "nine"};
 
    /* The first string is not used, it is to make array indexing simple */
    char *two_digits[] = {"", "ten", "eleven", "twelve", "thirteen", "fourteen",
                     "fifteen", "sixteen", "seventeen", "eighteen", "nineteen"};
 
    /* The first two string are not used, they are to make array indexing simple*/
    char *tens_multiple[] = {"", "", "twenty", "thirty", "forty", "fifty",
                             "sixty", "seventy", "eighty", "ninety"};
 
    char *tens_power[] = {"hundred", "thousand"};
 
    /* Used for debugging purpose only */
    printf("\n%s: ", num);
 
    /* For single digit number */
    if (len == 1) {
        printf("%s\n", single_digits[*num - '0']);
        return;
    }
 
     /* Iterate while num is not '\0' */
     while (*num != '\0') {
 
        /* Code path for first 2 digits */
        if (len >= 3) {
            if (*num -'0' != 0) {
                printf("%s ", single_digits[*num - '0']);
                printf("%s ", tens_power[len-3]); // here len can be 3 or 4
            }
            --len;
        }
 
        /* Code path for last 2 digits */
        else {
            /* Need to explicitly handle 10-19. Sum of the two digits is
               used as index of "two_digits" array of strings */
            if (*num == '1') {
                int sum = *num - '0' + *(num + 1)- '0';
                printf("%s\n", two_digits[sum]);
                return;
            }
 
            /* Need to explicitely handle 20 */
            else if (*num == '2' && *(num + 1) == '0') {
                printf("twenty\n");
                return;
            }
 
            /* Rest of the two digit numbers i.e., 21 to 99 */
            else {
                int i = *num - '0';
                printf("%s ", i? tens_multiple[i]: "");
                ++num;
                if (*num != '0')
                    printf("%s ", single_digits[*num - '0']);
            }
        }
        ++num;
    }
}

/* Driver program to test above function */
int main(void)
{
    convert_to_words("9923");
    convert_to_words("523");
    convert_to_words("89");
    convert_to_words("8989");
 
    return 0;
}

# %%
:D

# %% [markdown]
# ### Exercícios com bancos de dados

# %% [markdown]
# 1) Dada a tabela "pacientes", no banco de dados "Medicina", ilustrada abaixo:
#
#
# | idade | altura | peso | pressao_d | pressao_s |nome  |
# |-------|--------|------|-----------|-----------|------|
# | 23    | 183    | 73   | 8         | 12        |Rubens|
# | 42    | 167    | 60   | 7         | 11        |Maria |
# | 34    | 177    | 77   | 9         | 13        |Carlos|
#
#
#
# Escreva um script em Python + SQL para construir um dicionário tendo os nomes como chave e as idades como valores.

# %%
import sqlite3

conn = sqlite3.connect('Medicina_db')
cur = conn.cursor()

# %%
for i in cur.execute("CREATE TABLE paciente (idade integer, altura integer, peso integer, pressao_d integer, pressao_s integer, nome VARCHAR(20))"):
    print(i)

# %%
for i in cur.execute('PRAGMA table_info (paciente);'):
    print(i)
# Out:
# (0, 'idade', 'integer', 0, None, 0)
# (1, 'altura', 'integer', 0, None, 0)
# (2, 'peso', 'integer', 0, None, 0)
# (3, 'pressao_d', 'integer', 0, None, 0)
# (4, 'pressao_s', 'integer', 0, None, 0)
# (5, 'nome', 'VARCHAR(20)', 0, None, 0)

# %%
cur.execute("INSERT INTO paciente VALUES (23,183,73,8,12,'Rubens');")

# %%
for i in cur.execute("SELECT * from paciente;"):
    print(i)
# Out:
# (23, 183, 73, 8, 12, 'Rubens')

# %% [markdown]
# 2) Conecte ao banco Python/Dados/chinook.sqlite e inspecione a lista de tabelas

# %%
conn = sqlite3.connect('chinook.sqlite')
cur = conn.cursor()

# %%
for i in cur.execute("select name from sqlite_master where type='table';"):
    print(i)
# Out:
# ('albums',)
# ('sqlite_sequence',)
# ('artists',)
# ('customers',)
# ('employees',)
# ('genres',)
# ('invoices',)
# ('invoice_items',)
# ('media_types',)
# ('playlists',)
# ('playlist_track',)
# ('tracks',)
# ('sqlite_stat1',)

# %% [markdown]
# 3) Quais artistas lançaram mais albuns?

# %%
for i in cur.execute('PRAGMA table_info (albums);'):
    print(i)
# Out:
# (0, 'AlbumId', 'INTEGER', 1, None, 1)
# (1, 'Title', 'NVARCHAR(160)', 1, None, 0)
# (2, 'ArtistId', 'INTEGER', 1, None, 0)

# %%
for i in cur.execute('PRAGMA table_info (artists);'):
    print(i)
# Out:
# (0, 'ArtistId', 'INTEGER', 1, None, 1)
# (1, 'Name', 'NVARCHAR(120)', 0, None, 0)

# %%
q='''
SELECT artists.name, count(artists.name) as number
from albums 
inner join artists
on albums.artistID=artists.artistID 
group by artists.name
order by number
DESC;
'''

for i in cur.execute(q):
    print(i)
# Out:
# ('Iron Maiden', 21)
# ('Led Zeppelin', 14)
# ('Deep Purple', 11)
# ('Metallica', 10)
# ('U2', 10)
# ('Ozzy Osbourne', 6)
# ('Pearl Jam', 5)
# ('Faith No More', 4)
# ('Foo Fighters', 4)
# ('Lost', 4)
# ('Van Halen', 4)
# ('Various Artists', 4)
# ('Audioslave', 3)
# ('Berliner Philharmoniker & Herbert Von Karajan', 3)
# ('Eugene Ormandy', 3)
# ('Gilberto Gil', 3)
# ("Guns N' Roses", 3)
# ('Jamiroquai', 3)
# ('Miles Davis', 3)
# ('Os Paralamas Do Sucesso', 3)
# ('Queen', 3)
# ('R.E.M.', 3)
# ('Red Hot Chili Peppers', 3)
# ('Santana', 3)
# ('The Office', 3)
# ('The Rolling Stones', 3)
# ('AC/DC', 2)
# ('Accept', 2)
# ('Amy Winehouse', 2)
# ('Antônio Carlos Jobim', 2)
# ('Battlestar Galactica', 2)
# ('Black Label Society', 2)
# ('Black Sabbath', 2)
# ('Caetano Veloso', 2)
# ('Chico Science & Nação Zumbi', 2)
# ('Cidade Negra', 2)
# ('Creedence Clearwater Revival', 2)
# ('Cássia Eller', 2)
# ('Djavan', 2)
# ('English Concert & Trevor Pinnock', 2)
# ('Eric Clapton', 2)
# ('Green Day', 2)
# ('Kiss', 2)
# ('Legião Urbana', 2)
# ('Lulu Santos', 2)
# ('Michael Tilson Thomas & San Francisco Symphony', 2)
# ('Milton Nascimento', 2)
# ('Nirvana', 2)
# ('Skank', 2)
# ('Smashing Pumpkins', 2)
# ('Spyro Gyra', 2)
# ('The Black Crowes', 2)
# ('The Cult', 2)
# ('The Tea Party', 2)
# ('Tim Maia', 2)
# ('Titãs', 2)
# ('Aaron Copland & London Symphony Orchestra', 1)
# ('Aaron Goldberg', 1)
# ('Academy of St. Martin in the Fields & Sir Neville Marriner', 1)
# ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', 1)
# ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 1)
# ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 1)
# ('Adrian Leaper & Doreen de Feis', 1)
# ('Aerosmith', 1)
# ('Aisha Duo', 1)
# ('Alanis Morissette', 1)
# ('Alberto Turco & Nova Schola Gregoriana', 1)
# ('Alice In Chains', 1)
# ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 1)
# ('Antal Doráti & London Symphony Orchestra', 1)
# ('Apocalyptica', 1)
# ('Aquaman', 1)
# ('BackBeat', 1)
# ('Barry Wordsworth & BBC Concert Orchestra', 1)
# ('Battlestar Galactica (Classic)', 1)
# ('Berliner Philharmoniker & Hans Rosbaud', 1)
# ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 1)
# ('Billy Cobham', 1)
# ('Body Count', 1)
# ('Boston Symphony Orchestra & Seiji Ozawa', 1)
# ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', 1)
# ('Bruce Dickinson', 1)
# ('Buddy Guy', 1)
# ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', 1)
# ('Cake', 1)
# ('Calexico', 1)
# ("Charles Dutoit & L'Orchestre Symphonique de Montréal", 1)
# ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 1)
# ('Chicago Symphony Orchestra & Fritz Reiner', 1)
# ('Chico Buarque', 1)
# ('Choir Of Westminster Abbey & Simon Preston', 1)
# ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 1)
# ('Chris Cornell', 1)
# ("Christopher O'Riley", 1)
# ('Cláudio Zoli', 1)
# ('David Coverdale', 1)
# ('Def Leppard', 1)
# ('Dennis Chambers', 1)
# ('Dread Zeppelin', 1)
# ('Ed Motta', 1)
# ('Edo de Waart & San Francisco Symphony', 1)
# ('Elis Regina', 1)
# ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 1)
# ('Emerson String Quartet', 1)
# ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 1)
# ('Falamansa', 1)
# ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 1)
# ('Frank Sinatra', 1)
# ('Frank Zappa & Captain Beefheart', 1)
# ('Fretwork', 1)
# ('Funk Como Le Gusta', 1)
# ('Gene Krupa', 1)
# ('Gerald Moore', 1)
# ('Godsmack', 1)
# ('Gonzaguinha', 1)
# ('Gustav Mahler', 1)
# ('Göteborgs Symfoniker & Neeme Järvi', 1)
# ('Habib Koité and Bamada', 1)
# ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', 1)
# ('Heroes', 1)
# ('Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', 1)
# ('House Of Pain', 1)
# ('Incognito', 1)
# ('Itzhak Perlman', 1)
# ('JET', 1)
# ('James Brown', 1)
# ('James Levine', 1)
# ('Jimi Hendrix', 1)
# ('Joe Satriani', 1)
# ('Jorge Ben', 1)
# ('Jota Quest', 1)
# ('João Suplicy', 1)
# ('Judas Priest', 1)
# ('Julian Bream', 1)
# ('Karsh Kale', 1)
# ("Kent Nagano and Orchestre de l'Opéra de Lyon", 1)
# ('Lenny Kravitz', 1)
# ('Leonard Bernstein & New York Philharmonic', 1)
# ('Les Arts Florissants & William Christie', 1)
# ('London Symphony Orchestra & Sir Charles Mackerras', 1)
# ('Luciana Souza/Romero Lubambo', 1)
# ('Luciano Pavarotti', 1)
# ('Marcos Valle', 1)
# ('Marillion', 1)
# ('Marisa Monte', 1)
# ('Martin Roscoe', 1)
# ('Marvin Gaye', 1)
# ('Maurizio Pollini', 1)
# ('Mela Tenenbaum, Pro Musica Prague & Richard Kapp', 1)
# ('Men At Work', 1)
# ('Michele Campanella', 1)
# ('Motörhead', 1)
# ('Mônica Marianno', 1)
# ('Mötley Crüe', 1)
# ('Nash Ensemble', 1)
# ('Nicolaus Esterhazy Sinfonia', 1)
# ('O Rappa', 1)
# ('O Terço', 1)
# ('Olodum', 1)
# ('Orchestra of The Age of Enlightenment', 1)
# ('Orchestre Révolutionnaire et Romantique & John Eliot Gardiner', 1)
# ('Os Mutantes', 1)
# ('Otto Klemperer & Philharmonia Orchestra', 1)
# ('Page & Plant', 1)
# ('Passengers', 1)
# ("Paul D'Ianno", 1)
# ('Philharmonia Orchestra & Sir Neville Marriner', 1)
# ('Philip Glass Ensemble', 1)
# ('Pink Floyd', 1)
# ('Planet Hemp', 1)
# ('R.E.M. Feat. Kate Pearson', 1)
# ('Raimundos', 1)
# ('Raul Seixas', 1)
# ('Richard Marlow & The Choir of Trinity College, Cambridge', 1)
# ('Roger Norrington, London Classical Players', 1)
# ('Royal Philharmonic Orchestra & Sir Thomas Beecham', 1)
# ('Rush', 1)
# ('Scholars Baroque Ensemble', 1)
# ('Scorpions', 1)
# ('Sergei Prokofiev & Yuri Temirkanov', 1)
# ('Sir Georg Solti & Wiener Philharmoniker', 1)
# ('Sir Georg Solti, Sumi Jo & Wiener Philharmoniker', 1)
# ('Soundgarden', 1)
# ('Stevie Ray Vaughan & Double Trouble', 1)
# ('Stone Temple Pilots', 1)
# ('System Of A Down', 1)
# ('Temple of the Dog', 1)
# ('Terry Bozzio, Tony Levin & Steve Stevens', 1)
# ('The 12 Cellists of The Berlin Philharmonic', 1)
# ('The Clash', 1)
# ('The Doors', 1)
# ("The King's Singers", 1)
# ('The Police', 1)
# ('The Posies', 1)
# ('The Who', 1)
# ('Ton Koopman', 1)
# ('Toquinho & Vinícius', 1)
# ('UB40', 1)
# ('Velvet Revolver', 1)
# ('Vinícius De Moraes', 1)
# ('Wilhelm Kempff', 1)
# ('Yehudi Menuhin', 1)
# ('Yo-Yo Ma', 1)
# ('Zeca Pagodinho', 1)

# %% [markdown]
# 4) Quais gêneros musicais contêm mais faixas gravadas(tracks)?

# %%
for i in cur.execute('PRAGMA table_info (genres);'):
    print(i)
# Out:
# (0, 'GenreId', 'INTEGER', 1, None, 1)
# (1, 'Name', 'NVARCHAR(120)', 0, None, 0)

# %%
for i in cur.execute('PRAGMA table_info (tracks);'):
    print(i)
# Out:
# (0, 'TrackId', 'INTEGER', 1, None, 1)
# (1, 'Name', 'NVARCHAR(200)', 1, None, 0)
# (2, 'AlbumId', 'INTEGER', 0, None, 0)
# (3, 'MediaTypeId', 'INTEGER', 1, None, 0)
# (4, 'GenreId', 'INTEGER', 0, None, 0)
# (5, 'Composer', 'NVARCHAR(220)', 0, None, 0)
# (6, 'Milliseconds', 'INTEGER', 1, None, 0)
# (7, 'Bytes', 'INTEGER', 0, None, 0)
# (8, 'UnitPrice', 'NUMERIC(10,2)', 1, None, 0)

# %%
q ='''
SELECT genres.name, COUNT(tracks.TrackID) as number
from genres
inner join tracks
ON genres.genreID=tracks.GenreID
group by tracks.genreID
order by number
desc;
'''

# %%
for i in cur.execute(q):
    print(i)
# Out:
# ('Rock', 1297)
# ('Latin', 579)
# ('Metal', 374)
# ('Alternative & Punk', 332)
# ('Jazz', 130)
# ('TV Shows', 93)
# ('Blues', 81)
# ('Classical', 74)
# ('Drama', 64)
# ('R&B/Soul', 61)
# ('Reggae', 58)
# ('Pop', 48)
# ('Soundtrack', 43)
# ('Alternative', 40)
# ('Hip Hop/Rap', 35)
# ('Electronica/Dance', 30)
# ('Heavy Metal', 28)
# ('World', 28)
# ('Sci Fi & Fantasy', 26)
# ('Easy Listening', 24)
# ('Comedy', 17)
# ('Bossa Nova', 15)
# ('Science Fiction', 13)
# ('Rock And Roll', 12)
# ('Opera', 1)

# %% [markdown]
# 5) Quais os clientes (customers) que gastaram mais dinheiro em compras (invoices)?

# %%
for i in cur.execute('PRAGMA table_info (customers);'):
    print(i)
# Out:
# (0, 'CustomerId', 'INTEGER', 1, None, 1)
# (1, 'FirstName', 'NVARCHAR(40)', 1, None, 0)
# (2, 'LastName', 'NVARCHAR(20)', 1, None, 0)
# (3, 'Company', 'NVARCHAR(80)', 0, None, 0)
# (4, 'Address', 'NVARCHAR(70)', 0, None, 0)
# (5, 'City', 'NVARCHAR(40)', 0, None, 0)
# (6, 'State', 'NVARCHAR(40)', 0, None, 0)
# (7, 'Country', 'NVARCHAR(40)', 0, None, 0)
# (8, 'PostalCode', 'NVARCHAR(10)', 0, None, 0)
# (9, 'Phone', 'NVARCHAR(24)', 0, None, 0)
# (10, 'Fax', 'NVARCHAR(24)', 0, None, 0)
# (11, 'Email', 'NVARCHAR(60)', 1, None, 0)
# (12, 'SupportRepId', 'INTEGER', 0, None, 0)

# %%
for i in cur.execute('PRAGMA table_info (invoices);'):
    print(i)
# Out:
# (0, 'InvoiceId', 'INTEGER', 1, None, 1)
# (1, 'CustomerId', 'INTEGER', 1, None, 0)
# (2, 'InvoiceDate', 'DATETIME', 1, None, 0)
# (3, 'BillingAddress', 'NVARCHAR(70)', 0, None, 0)
# (4, 'BillingCity', 'NVARCHAR(40)', 0, None, 0)
# (5, 'BillingState', 'NVARCHAR(40)', 0, None, 0)
# (6, 'BillingCountry', 'NVARCHAR(40)', 0, None, 0)
# (7, 'BillingPostalCode', 'NVARCHAR(10)', 0, None, 0)
# (8, 'Total', 'NUMERIC(10,2)', 1, None, 0)

# %%
q = '''
select customers.FirstName, customers.LastName, round(SUM(invoices.Total),2) as soma
from customers
inner join
invoices
ON customers.customerID = invoices.customerID
group by customers.customerID
order by soma
desc;
'''

# %%
for i in cur.execute(q):
    print(i)
# Out:
# ('Helena', 'Holý', 49.62)
# ('Richard', 'Cunningham', 47.62)
# ('Luis', 'Rojas', 46.62)
# ('Ladislav', 'Kovács', 45.62)
# ('Hugh', "O'Reilly", 45.62)
# ('Frank', 'Ralston', 43.62)
# ('Julia', 'Barnett', 43.62)
# ('Fynn', 'Zimmermann', 43.62)
# ('Astrid', 'Gruber', 42.62)
# ('Victor', 'Stevens', 42.62)
# ('Terhi', 'Hämäläinen', 41.62)
# ('František', 'Wichterlová', 40.62)
# ('Isabelle', 'Mercier', 40.62)
# ('Johannes', 'Van der Berg', 40.62)
# ('Luís', 'Gonçalves', 39.62)
# ('François', 'Tremblay', 39.62)
# ('Bjørn', 'Hansen', 39.62)
# ('Jack', 'Smith', 39.62)
# ('Dan', 'Miller', 39.62)
# ('Heather', 'Leacock', 39.62)
# ('João', 'Fernandes', 39.62)
# ('Wyatt', 'Girard', 39.62)
# ('Jennifer', 'Peterson', 38.62)
# ('Tim', 'Goyer', 38.62)
# ('Camille', 'Bernard', 38.62)
# ('Dominique', 'Lefebvre', 38.62)
# ('Joakim', 'Johansson', 38.62)
# ('Manoj', 'Pareek', 38.62)
# ('Leonie', 'Köhler', 37.62)
# ('Daan', 'Peeters', 37.62)
# ('Kara', 'Nielsen', 37.62)
# ('Eduardo', 'Martins', 37.62)
# ('Alexandre', 'Rocha', 37.62)
# ('Roberto', 'Almeida', 37.62)
# ('Fernanda', 'Ramos', 37.62)
# ('Mark', 'Philips', 37.62)
# ('Frank', 'Harris', 37.62)
# ('Michelle', 'Brooks', 37.62)
# ('Kathy', 'Chase', 37.62)
# ('John', 'Gordon', 37.62)
# ('Patrick', 'Gray', 37.62)
# ('Robert', 'Brown', 37.62)
# ('Edward', 'Francis', 37.62)
# ('Martha', 'Silk', 37.62)
# ('Aaron', 'Mitchell', 37.62)
# ('Ellie', 'Sullivan', 37.62)
# ('Madalena', 'Sampaio', 37.62)
# ('Hannah', 'Schneider', 37.62)
# ('Niklas', 'Schröder', 37.62)
# ('Marc', 'Dubois', 37.62)
# ('Lucas', 'Mancini', 37.62)
# ('Stanisław', 'Wójcik', 37.62)
# ('Enrique', 'Muñoz', 37.62)
# ('Emma', 'Jones', 37.62)
# ('Phil', 'Hughes', 37.62)
# ('Steve', 'Murray', 37.62)
# ('Mark', 'Taylor', 37.62)
# ('Diego', 'Gutiérrez', 37.62)
# ('Puja', 'Srivastava', 36.64)

# %% [markdown]
# 6) Quais foram as faixas mais compradas, e de qual artista são?

# %%
for i in cur.execute('PRAGMA table_info (tracks);'):
    print(i)
# Out:
# (0, 'TrackId', 'INTEGER', 1, None, 1)
# (1, 'Name', 'NVARCHAR(200)', 1, None, 0)
# (2, 'AlbumId', 'INTEGER', 0, None, 0)
# (3, 'MediaTypeId', 'INTEGER', 1, None, 0)
# (4, 'GenreId', 'INTEGER', 0, None, 0)
# (5, 'Composer', 'NVARCHAR(220)', 0, None, 0)
# (6, 'Milliseconds', 'INTEGER', 1, None, 0)
# (7, 'Bytes', 'INTEGER', 0, None, 0)
# (8, 'UnitPrice', 'NUMERIC(10,2)', 1, None, 0)

# %%
for i in cur.execute('PRAGMA table_info (invoice_items);'):
    print(i)
# Out:
# (0, 'InvoiceLineId', 'INTEGER', 1, None, 1)
# (1, 'InvoiceId', 'INTEGER', 1, None, 0)
# (2, 'TrackId', 'INTEGER', 1, None, 0)
# (3, 'UnitPrice', 'NUMERIC(10,2)', 1, None, 0)
# (4, 'Quantity', 'INTEGER', 1, None, 0)

# %%
for i in cur.execute('PRAGMA table_info (invoices);'):
    print(i)
# Out:
# (0, 'InvoiceId', 'INTEGER', 1, None, 1)
# (1, 'CustomerId', 'INTEGER', 1, None, 0)
# (2, 'InvoiceDate', 'DATETIME', 1, None, 0)
# (3, 'BillingAddress', 'NVARCHAR(70)', 0, None, 0)
# (4, 'BillingCity', 'NVARCHAR(40)', 0, None, 0)
# (5, 'BillingState', 'NVARCHAR(40)', 0, None, 0)
# (6, 'BillingCountry', 'NVARCHAR(40)', 0, None, 0)
# (7, 'BillingPostalCode', 'NVARCHAR(10)', 0, None, 0)
# (8, 'Total', 'NUMERIC(10,2)', 1, None, 0)

# %%
for i in cur.execute('PRAGMA table_info (albums);'):
    print(i)
# Out:
# (0, 'AlbumId', 'INTEGER', 1, None, 1)
# (1, 'Title', 'NVARCHAR(160)', 1, None, 0)
# (2, 'ArtistId', 'INTEGER', 1, None, 0)

# %%
q = '''
select uma.a, uma.soma, albums.title
from
(select tracks.name as a, sum(invoice_items.quantity) as soma, tracks.AlbumID as b
from invoice_items
inner join
tracks
ON tracks.TrackID = invoice_items.TrackID
group by tracks.TrackID
order by soma
desc) as uma
inner join
albums
ON uma.b = albums.AlbumID;
'''

# %%
for i in cur.execute(q):
    print(i)
# Out:
# ('Balls to the Wall', 2, 'Balls to the Wall')
# ('Inject The Venom', 2, 'For Those About To Rock We Salute You')
# ('Snowballed', 2, 'For Those About To Rock We Salute You')
# ('Overdose', 2, 'Let There Be Rock')
# ('Deuces Are Wild', 2, 'Big Ones')
# ('Not The Doctor', 2, 'Jagged Little Pill')
# ('Por Causa De Você', 2, 'Warner 25 Anos')
# ('Welcome Home (Sanitarium)', 2, 'Plays Metallica By Four Cellos')
# ('Snowblind', 2, 'Black Sabbath Vol. 4 (Remaster)')
# ('Cornucopia', 2, 'Black Sabbath Vol. 4 (Remaster)')
# ('Bowels Of The Devil', 2, 'Body Count')
# ('Voodoo', 2, 'Body Count')
# ('Chemical Wedding', 2, 'Chemical Wedding')
# ('When My Left Eye Jumps', 2, 'The Best Of Buddy Guy - The Millenium Collection')
# ('Meditação', 2, 'Prenda Minha')
# ('Bem Devagar', 2, 'Prenda Minha')
# ('Mel', 2, 'Prenda Minha')
# ('Samba De Orly', 2, 'Minha Historia')
# ('Morena De Angola', 2, 'Minha Historia')
# ('Meu Caro Amigo', 2, 'Minha Historia')
# ('Geni E O Zepelim', 2, 'Minha Historia')
# ('Samba Do Lado', 2, 'Afrociberdelia')
# ('Amor De Muito', 2, 'Afrociberdelia')
# ('Lixo Do Mangue', 2, 'Da Lama Ao Caos')
# ('A Cor Do Sol', 2, 'Acústico MTV [Live]')
# ('Linha Do Equador', 2, 'Na Pista')
# ('Tarde Em Itapoã', 2, 'Chill: Brazil (Disc 2)')
# ('Tanto Tempo', 2, 'Chill: Brazil (Disc 2)')
# ('Bumbo Da Mangueira', 2, 'Chill: Brazil (Disc 2)')
# ('Só Tinha De Ser Com Você', 2, 'Chill: Brazil (Disc 2)')
# ('Whiskey In The Jar', 2, 'Garage Inc. (Disc 1)')
# ("I'm Going Slightly Mad", 2, 'Greatest Hits II')
# ('Sure Know Something', 2, 'Greatest Kiss')
# ('Shock Me', 2, 'Greatest Kiss')
# ('Calling Dr. Love', 2, 'Greatest Kiss')
# ('Surrender', 2, 'Heart of the Night')
# ('J Squared', 2, 'Heart of the Night')
# ('Basket Case', 2, 'International Superhits')
# ('When I Come Around', 2, 'International Superhits')
# ('Nice Guys Finish Last', 2, 'International Superhits')
# ('Living On Love', 2, 'Into The Light')
# ('Comportamento Geral', 2, 'Meus Momentos')
# ('Ando Meio Desligado', 2, 'Minha História')
# ('Smoke On The Water', 2, 'MK III The Final Concerts [Disc 1]')
# ('Blue Rythm Fantasy', 2, "Up An' Atom")
# ('Drum Boogie', 2, "Up An' Atom")
# ('Lemon Drop', 2, "Up An' Atom")
# ("Don't Take Your Love From Me", 2, "Up An' Atom")
# ('Onde Anda Você', 2, 'Vinícius De Moraes - Sem Limite')
# ('Pela Luz dos Olhos Teus (Miúcha e Tom Jobim)', 2, 'Vozes do MPB')
# ('As Rosas Não Falam (Beth Carvalho)', 2, 'Vozes do MPB')
# ('Susie Q', 2, 'Chronicle, Vol. 1')
# ('Commotion', 2, 'Chronicle, Vol. 1')
# ('Sweet Hitch-Hiker', 2, 'Chronicle, Vol. 1')
# ('Good Golly Miss Molly', 2, 'Chronicle, Vol. 2')
# ("Don't Look Now", 2, 'Chronicle, Vol. 2')
# ('The Midnight Special', 2, 'Chronicle, Vol. 2')
# ('Brasil', 2, 'Cássia Eller - Coleção Sem Limite [Disc 2]')
# ('Woman Is The Nigger Of The World (Ao Vivo)', 2, 'Cássia Eller - Coleção Sem Limite [Disc 2]')
# ('Mis Penas Lloraba Yo (Ao Vivo) Soy Gitano (Tangos)', 2, 'Cássia Eller - Sem Limite [Disc 1]')
# ('No No No', 2, 'Fireball')
# ("Maybe I'm A Leo", 2, 'Machine Head')
# ('Álibi', 2, 'Djavan Ao Vivo - Vol. 02')
# ('Esquinas', 2, 'Djavan Ao Vivo - Vol. 02')
# ('Açai', 2, 'Djavan Ao Vivo - Vol. 1')
# ('Azul', 2, 'Djavan Ao Vivo - Vol. 1')
# ('Dois Pra Lá, Dois Pra Cá', 2, 'Elis Regina-Minha História')
# ('Sunshine Of Your Love', 2, 'The Cream Of Clapton')
# ('Lay Down Sally', 2, 'The Cream Of Clapton')
# ('Promises', 2, 'The Cream Of Clapton')
# ('Lonely Stranger', 2, 'Unplugged')
# ('Last Cup Of Sorrow', 2, 'Album Of The Year')
# ('She Loves Me Not', 2, 'Album Of The Year')
# ('Caffeine', 2, 'Angel Dust')
# ('Midlife Crisis', 2, 'Angel Dust')
# ('Easy', 2, 'Angel Dust')
# ('What A Day', 2, 'King For A Day Fool For A Lifetime')
# ('Falamansa Song', 2, 'Deixa Entrar')
# ('The Last Song', 2, 'In Your Honor [Disc 1]')
# ('Times Like These', 2, 'One By One')
# ('Is This Love (Live)', 2, 'Quanta Gente Veio Ver (Live)')
# ('Stir It Up (Live)', 2, 'Quanta Gente Veio Ver (Live)')
# ('A Novidade (Live)', 2, 'Quanta Gente Veio Ver (Live)')
# ('Lamento De Carnaval', 2, 'Quanta Gente Veio ver--Bônus De Carnaval')
# ('Beira Mar', 2, 'Unplugged')
# ('Re-Align', 2, 'Faceless')
# ('Holiday', 2, 'American Idiot')
# ('Give Me Novacaine', 2, 'American Idiot')
# ('Whatsername', 2, 'American Idiot')
# ('Rocket Queen', 2, 'Appetite for Destruction')
# ('Perfect Crime', 2, 'Use Your Illusion I')
# ('The Garden', 2, 'Use Your Illusion I')
# ('Garden of Eden', 2, 'Use Your Illusion I')
# ('Breakdown', 2, 'Use Your Illusion II')
# ("L'Arc En Ciel De Miles", 2, 'Blue Moods')
# ('For the Greater Good of God', 2, 'A Matter of Life and Death')
# ('Can I Play With Madness', 2, 'A Real Live One')
# ('The Thin Line Between Love & Hate', 2, 'Brave New World')
# ('Hallowed Be Thy Name', 2, 'Live At Donington 1992 (Disc 2)')
# ('The Trooper', 2, 'Live At Donington 1992 (Disc 2)')
# ('Run Silent Run Deep', 2, 'No Prayer For The Dying')
# ('Where Eagles Dare', 2, 'Piece Of Mind')
# ('Aces High', 2, 'Powerslave')
# ('Blood Brothers', 2, 'Rock In Rio [CD1]')
# ('The Number Of The Beast', 2, 'Rock In Rio [CD2]')
# ('Moonchild', 2, 'Seventh Son of a Seventh Son')
# ('The Clairvoyant', 2, 'Seventh Son of a Seventh Son')
# ('Gangland', 2, 'The Number of The Beast')
# ('The Prisoner', 2, 'The Number of The Beast')
# ('The Aftermath', 2, 'The X Factor')
# ('Judgement Of Heaven', 2, 'The X Factor')
# ("Don't Look To The Eyes Of A Stranger", 2, 'Virtual XI')
# ('Hey America', 2, 'Sex Machine')
# ("Whatever It Is, I Just Can't Stop", 2, 'Emergency On Planet Earth')
# ('Light Years', 2, 'The Return Of The Space Cowboy')
# ('Take It Or Leave It', 2, 'Get Born')
# ("You've Got Another Thing Comin'", 2, 'Living After Midnight')
# ('Turbo Lover', 2, 'Living After Midnight')
# ('Plaster Caster', 2, 'Unplugged [Live]')
# ('Sure Know Something', 2, 'Unplugged [Live]')
# ('Rock And Roll All Nite', 2, 'Unplugged [Live]')
# ("Walter's Walk", 2, 'Coda')
# ('Dancing Days', 2, 'Houses Of The Holy')
# ('In The Evening', 2, 'In Through The Out Door')
# ("I'm Gonna Crawl", 2, 'In Through The Out Door')
# ('Dazed and Confused', 2, 'Led Zeppelin I')
# ('How Many More Times', 2, 'Led Zeppelin I')
# ("Living Loving Maid (She's Just A Woman)", 2, 'Led Zeppelin II')
# ('Ramble On', 2, 'Led Zeppelin II')
# ('Bron-Y-Aur Stomp', 2, 'Led Zeppelin III')
# ('For Your Life', 2, 'Presence')
# ("L'Avventura", 2, 'A TempestadeTempestade Ou O Livro Dos Dias')
# ('Tempo Perdido', 2, 'Mais Do Mesmo')
# ('Mr. Cab Driver', 2, 'Greatest Hits')
# ('Abraham, Martin And John', 2, 'Seek And Shall Find: More Of The Best (1963-1981)')
# ('Save The Children', 2, 'Seek And Shall Find: More Of The Best (1963-1981)')
# ('Down by the Sea', 2, 'The Best Of Men At Work')
# ('Shakes and Ladders', 2, 'The Best Of Men At Work')
# ('Nothing Else Matters', 2, 'Black Album')
# ('Stone Cold Crazy', 2, 'Garage Inc. (Disc 2)')
# ('Motorbreath', 2, "Kill 'Em All")
# ('Phantom Lord', 2, "Kill 'Em All")
# ('The House Jack Built', 2, 'Load')
# ('Battery', 2, 'Master Of Puppets')
# ('Leper Messiah', 2, 'Master Of Puppets')
# ('The Unforgiven II', 2, 'ReLoad')
# ('Better Than You', 2, 'ReLoad')
# ('For Whom The Bell Tolls', 2, 'Ride The Lightning')
# ('Shoot Me Again', 2, 'St. Anger')
# ('The Duke', 2, 'Miles Ahead')
# ('Menestrel Das Alagoas', 2, 'Milton Nascimento Ao Vivo')
# ('Norwegian Wood', 2, 'Minas')
# ('Sangue Latino', 2, 'Compositores')
# ('Folhas Secas', 2, 'Compositores')
# ('Menino De Rua', 2, 'Compositores')
# ('Nossa Gente (Avisa Là)', 2, 'Olodum')
# ('Revolta Olodum', 2, 'Olodum')
# ('Selvagem', 2, 'Acústico MTV')
# ('Nebulosa Do Amor', 2, 'Acústico MTV')
# ('Mensagen De Amor (2000)', 2, 'Arquivo II')
# ('Saber Amar', 2, 'Arquivo II')
# ('Meu Erro', 2, 'Arquivo Os Paralamas Do Sucesso')
# ('Romance Ideal', 2, 'Arquivo Os Paralamas Do Sucesso')
# ('Flying High Again', 2, 'Diary of a Madman (Remastered)')
# ("Mama, I'm Coming Home", 2, 'No More Tears (Remastered)')
# ('Children Of The Grave', 2, 'Tribute')
# ('Walking Into Clarksdale', 2, 'Walking Into Clarksdale')
# ('Plot 180', 2, 'Original Soundtracks 1')
# ('Untitled', 2, 'Live On Two Legs [Live]')
# ('Big Wave', 2, 'Pearl Jam')
# ('Rappers Reais', 2, 'Os Cães Ladram Mas A Caravana Não Pára')
# ('Nega Do Cabelo Duro', 2, 'Os Cães Ladram Mas A Caravana Não Pára')
# ("You're My Best Friend", 2, 'Greatest Hits I')
# ('Somebody To Love', 2, 'Greatest Hits I')
# ('We Are The Champions', 2, 'News Of The World')
# ('Get Up', 2, 'Green')
# ('Untitled', 2, 'Green')
# ('Undertow', 2, 'New Adventures In Hi-Fi')
# ('Binky The Doormat', 2, 'New Adventures In Hi-Fi')
# ('Country Feedback', 2, 'Out Of Time')
# ('So Central Rain', 2, 'The Best Of R.E.M.: The IRS Years')
# ('Fall On Me', 2, 'The Best Of R.E.M.: The IRS Years')
# ('I Believe', 2, 'The Best Of R.E.M.: The IRS Years')
# ('Esporrei Na Manivela', 2, 'Cesta Básica')
# ('Que Luz É Essa', 2, 'Raul Seixas')
# ('Under The Bridge', 2, 'Blood Sugar Sex Magik')
# ('Tear', 2, 'By The Way')
# ('Right On Time', 2, 'Californication')
# ('Waiting', 2, 'Judas 0: B-Sides and Rarities')
# ('Saturnine', 2, 'Judas 0: B-Sides and Rarities')
# ('Cherub Rock', 2, 'Rotten Apples: Greatest Hits')
# ('Bullet With Butterfly Wings', 2, 'Rotten Apples: Greatest Hits')
# ('Real Love', 2, 'Rotten Apples: Greatest Hits')
# ('Pretty Noose', 2, 'A-Sides')
# ('Starburst', 2, 'Morning Dance')
# ('End Of Romanticism', 2, 'Morning Dance')
# ('Travis Walk', 2, 'In Step')
# ('Piece Of Pie', 2, 'Core')
# ('Soldier Side - Intro', 2, 'Mezmerize')
# ('Violent Pornography', 2, 'Mezmerize')
# ('Question!', 2, 'Mezmerize')
# ('Midnight From The Inside Out', 2, 'Live [Disc 1]')
# ('Title Song', 2, 'Live [Disc 2]')
# ('Train In Vain', 2, 'The Singles')
# ('Speed Of Light', 2, 'Beyond Good And Evil')
# ('Sun King', 2, 'Pure Cult: The Best Of The Cult (For Rockers, Ravers, Lovers & Sinners) [UK]')
# ('Release', 2, 'Tangents')
# ('Heaven Coming Down', 2, 'Tangents')
# ('Gyroscope', 2, 'Transmission')
# ('Babylon', 2, 'Transmission')
# ('Boris The Spider', 2, 'My Generation - The Very Best Of The Who')
# ('You Better You Bet', 2, 'My Generation - The Very Best Of The Who')
# ('Música No Ar', 2, 'Serie Sem Limite (Disc 1)')
# ('Compadre', 2, 'Serie Sem Limite (Disc 1)')
# ('Não Quero Dinheiro', 2, 'Serie Sem Limite (Disc 2)')
# ('Comida', 2, 'Acústico')
# ('O Pulso', 2, 'Acústico')
# ('A Melhor Forma', 2, 'Acústico')
# ('Cabeça Dinossauro', 2, 'Acústico')
# ('Lugar Nenhum', 2, 'Volume Dois')
# ('Toda Cor', 2, 'Volume Dois')
# ('The Woman King', 2, 'Battlestar Galactica, Season 3')
# ('The Fix', 2, 'Heroes, Season 1')
# ('Walkabout', 2, 'Lost, Season 1')
# ('Peace On Earth', 2, "All That You Can't Leave Behind")
# ('When I Look At The World', 2, "All That You Can't Leave Behind")
# ('Everlasting Love', 2, 'B-Sides 1980-1990')
# ('Hallelujah Here She Comes', 2, 'B-Sides 1980-1990')
# ('City Of Blinding Lights', 2, 'How To Dismantle An Atomic Bomb')
# ('Miami', 2, 'Pop')
# ('All Along The Watchtower', 2, 'Rattle And Hum')
# ('Pride (In The Name Of Love)', 2, 'Rattle And Hum')
# ('The Star Spangled Banner', 2, 'Rattle And Hum')
# ('Sweetest Thing', 2, 'The Best Of 1980-1990')
# ('Sunday Bloody Sunday', 2, 'War')
# ('Two Hearts Beat As One', 2, 'War')
# ('Red Light', 2, 'War')
# ('Dirty Day', 2, 'Zooropa')
# ("C'est La Vie", 2, 'UB40 The Best Of - Volume Two [UK]')
# ('Eruption', 2, 'The Best Of Van Halen, Vol. I')
# ('Eruption', 2, 'Van Halen')
# ('Year to the Day', 2, 'Van Halen III')
# ('Hot Girl', 2, 'The Office, Season 1')
# ('Gay Witch Hunt', 2, 'The Office, Season 3')
# ("Phyllis's Wedding", 2, 'The Office, Season 3')
# ('How to Stop an Exploding Man', 2, 'Heroes, Season 1')
# ('Pilot', 2, 'Aquaman')
# ('Give Peace a Chance', 2, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('Beautiful Boy', 2, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('War Pigs', 2, 'Speak of the Devil')
# ("Scheherazade, Op. 35: I. The Sea and Sindbad's Ship", 2, 'Scheherazade')
# ("Symphonie Fantastique, Op. 14: V. Songe d'une nuit du sabbat", 2, 'Berlioz: Symphonie Fantastique')
# ('Rehab', 2, 'Back to Black')
# ('Suite No. 3 in D, BWV 1068: III. Gavotte I & II', 2, 'Bach: Orchestral Suites Nos. 1 - 4')
# ('Music for the Funeral of Queen Mary: VI. "Thou Knowest, Lord, the Secrets of Our Hearts"', 2, 'Purcell: Music for the Queen Mary')
# ('String Quartet No. 12 in C Minor, D. 703 "Quartettsatz": II. Andante - Allegro assai', 2, "Schubert: The Late String Quartets & String Quintet (3 CD's)")
# ('For Those About To Rock (We Salute You)', 1, 'For Those About To Rock We Salute You')
# ('Fast As a Shark', 1, 'Restless and Wild')
# ('Restless and Wild', 1, 'Restless and Wild')
# ('Princess of the Dawn', 1, 'Restless and Wild')
# ('Put The Finger On You', 1, 'For Those About To Rock We Salute You')
# ('Evil Walks', 1, 'For Those About To Rock We Salute You')
# ('Breaking The Rules', 1, 'For Those About To Rock We Salute You')
# ('Night Of The Long Knives', 1, 'For Those About To Rock We Salute You')
# ('Spellbound', 1, 'For Those About To Rock We Salute You')
# ('Go Down', 1, 'Let There Be Rock')
# ('Dog Eat Dog', 1, 'Let There Be Rock')
# ('Problem Child', 1, 'Let There Be Rock')
# ("Hell Ain't A Bad Place To Be", 1, 'Let There Be Rock')
# ('Love In An Elevator', 1, 'Big Ones')
# ('Rag Doll', 1, 'Big Ones')
# ('What It Takes', 1, 'Big Ones')
# ("Janie's Got A Gun", 1, 'Big Ones')
# ('Amazing', 1, 'Big Ones')
# ('Blind Man', 1, 'Big Ones')
# ('Angel', 1, 'Big Ones')
# ("Livin' On The Edge", 1, 'Big Ones')
# ('All I Really Want', 1, 'Jagged Little Pill')
# ('You Oughta Know', 1, 'Jagged Little Pill')
# ('Right Through You', 1, 'Jagged Little Pill')
# ('Forgiven', 1, 'Jagged Little Pill')
# ('You Learn', 1, 'Jagged Little Pill')
# ('Wake Up', 1, 'Jagged Little Pill')
# ('Sea Of Sorrow', 1, 'Facelift')
# ('Bleed The Freak', 1, 'Facelift')
# ("I Can't Remember", 1, 'Facelift')
# ("It Ain't Like That", 1, 'Facelift')
# ('Confusion', 1, 'Facelift')
# ('I Know Somethin (Bout You)', 1, 'Facelift')
# ('Real Thing', 1, 'Facelift')
# ('Ligia', 1, 'Warner 25 Anos')
# ('Falando De Amor', 1, 'Warner 25 Anos')
# ('Angela', 1, 'Warner 25 Anos')
# ('O Boto (Bôto)', 1, 'Warner 25 Anos')
# ('Canta, Canta Mais', 1, 'Warner 25 Anos')
# ('Master Of Puppets', 1, 'Plays Metallica By Four Cellos')
# ('The Unforgiven', 1, 'Plays Metallica By Four Cellos')
# ('Cochise', 1, 'Audioslave')
# ('Like a Stone', 1, 'Audioslave')
# ('Set It Off', 1, 'Audioslave')
# ('Exploder', 1, 'Audioslave')
# ('Hypnotize', 1, 'Audioslave')
# ('The Last Remaining Light', 1, 'Audioslave')
# ('Your Time Has Come', 1, 'Out Of Exile')
# ("Doesn't Remind Me", 1, 'Out Of Exile')
# ('Drown Me Slowly', 1, 'Out Of Exile')
# ('Yesterday To Tomorrow', 1, 'Out Of Exile')
# ('Dandelion', 1, 'Out Of Exile')
# ('Money', 1, 'BackBeat Soundtrack')
# ('Long Tall Sally', 1, 'BackBeat Soundtrack')
# ("C'Mon Everybody", 1, 'BackBeat Soundtrack')
# ("Rock 'N' Roll Music", 1, 'BackBeat Soundtrack')
# ('Carol', 1, 'BackBeat Soundtrack')
# ('Good Golly Miss Molly', 1, 'BackBeat Soundtrack')
# ('Spanish moss-"A sound portrait"-Spanish moss', 1, 'The Best Of Billy Cobham')
# ('Moon germs', 1, 'The Best Of Billy Cobham')
# ('Solo-Panhandler', 1, 'The Best Of Billy Cobham')
# ('Do what cha wanna', 1, 'The Best Of Billy Cobham')
# ('All For You', 1, 'Alcohol Fueled Brewtality Live! [Disc 1]')
# ('Super Terrorizer', 1, 'Alcohol Fueled Brewtality Live! [Disc 1]')
# ('Bored To Tears', 1, 'Alcohol Fueled Brewtality Live! [Disc 1]')
# ('A.N.D.R.O.T.A.Z.', 1, 'Alcohol Fueled Brewtality Live! [Disc 1]')
# ('The Begining... At Last', 1, 'Alcohol Fueled Brewtality Live! [Disc 1]')
# ('Heart Of Gold', 1, 'Alcohol Fueled Brewtality Live! [Disc 2]')
# ('Blood In The Wall', 1, 'Alcohol Fueled Brewtality Live! [Disc 2]')
# ('The Beginning...At Last', 1, 'Alcohol Fueled Brewtality Live! [Disc 2]')
# ('N.I.B.', 1, 'Black Sabbath')
# ('Evil Woman', 1, 'Black Sabbath')
# ("Tomorrow's Dream", 1, 'Black Sabbath Vol. 4 (Remaster)')
# ('Laguna Sunrise', 1, 'Black Sabbath Vol. 4 (Remaster)')
# ('Under The Sun/Every Day Comes and Goes', 1, 'Black Sabbath Vol. 4 (Remaster)')
# ('Smoked Pork', 1, 'Body Count')
# ("Body Count's In The House", 1, 'Body Count')
# ('Body Count', 1, 'Body Count')
# ('A Statistic', 1, 'Body Count')
# ('KKK Bitch', 1, 'Body Count')
# ('Evil Dick', 1, 'Body Count')
# ('Body Count Anthem', 1, 'Body Count')
# ('King In Crimson', 1, 'Chemical Wedding')
# ('The Tower', 1, 'Chemical Wedding')
# ('Killing Floor', 1, 'Chemical Wedding')
# ('Book Of Thel', 1, 'Chemical Wedding')
# ('Gates Of Urizen', 1, 'Chemical Wedding')
# ('Jerusalem', 1, 'Chemical Wedding')
# ('Trupets Of Jericho', 1, 'Chemical Wedding')
# ('Machine Men', 1, 'Chemical Wedding')
# ('The Alchemist', 1, 'Chemical Wedding')
# ('Realword', 1, 'Chemical Wedding')
# ('First Time I Met The Blues', 1, 'The Best Of Buddy Guy - The Millenium Collection')
# ('Let Me Love You Baby', 1, 'The Best Of Buddy Guy - The Millenium Collection')
# ('Stone Crazy', 1, 'The Best Of Buddy Guy - The Millenium Collection')
# ('Leave My Girl Alone', 1, 'The Best Of Buddy Guy - The Millenium Collection')
# ('My Time After Awhile', 1, 'The Best Of Buddy Guy - The Millenium Collection')
# ('Jorge Da Capadócia', 1, 'Prenda Minha')
# ('Prenda Minha', 1, 'Prenda Minha')
# ('Terra', 1, 'Prenda Minha')
# ('Eclipse Oculto', 1, 'Prenda Minha')
# ('Texto "Verdade Tropical"', 1, 'Prenda Minha')
# ('Saudosismo', 1, 'Prenda Minha')
# ('Carolina', 1, 'Prenda Minha')
# ('Sozinho', 1, 'Prenda Minha')
# ('Esse Cara', 1, 'Prenda Minha')
# ('Linha Do Equador', 1, 'Prenda Minha')
# ('Odara', 1, 'Prenda Minha')
# ('Atrás Da Verd-E-Rosa Só Não Vai Quem Já Morreu', 1, 'Prenda Minha')
# ('Vida Boa', 1, 'Prenda Minha')
# ('Sozinho (Hitmakers Classic Mix)', 1, 'Sozinho Remix Ao Vivo')
# ("Sozinho (Caêdrum 'n' Bass)", 1, 'Sozinho Remix Ao Vivo')
# ('Vai Passar', 1, 'Minha Historia')
# ('Bye, Bye Brasil', 1, 'Minha Historia')
# ('Atras Da Porta', 1, 'Minha Historia')
# ('Tatuagem', 1, 'Minha Historia')
# ('O Que Será (À Flor Da Terra)', 1, 'Minha Historia')
# ('Apesar De Você', 1, 'Minha Historia')
# ('A Banda', 1, 'Minha Historia')
# ('Minha Historia', 1, 'Minha Historia')
# ('Com Açúcar E Com Afeto', 1, 'Minha Historia')
# ('Trocando Em Miúdos', 1, 'Minha Historia')
# ("Gota D'água", 1, 'Minha Historia')
# ('Construção / Deus Lhe Pague', 1, 'Minha Historia')
# ('Mateus Enter', 1, 'Afrociberdelia')
# ('O Cidadão Do Mundo', 1, 'Afrociberdelia')
# ('Etnia', 1, 'Afrociberdelia')
# ('Um Passeio No Mundo Livre', 1, 'Afrociberdelia')
# ('Maracatu Atômico', 1, 'Afrociberdelia')
# ('Sobremesa', 1, 'Afrociberdelia')
# ('Manguetown', 1, 'Afrociberdelia')
# ('Um Satélite Na Cabeça', 1, 'Afrociberdelia')
# ('Sangue De Bairro', 1, 'Afrociberdelia')
# ('Interlude Zumbi', 1, 'Afrociberdelia')
# ('Criança De Domingo', 1, 'Afrociberdelia')
# ('Maracatu Atômico [Trip Hop]', 1, 'Afrociberdelia')
# ('Banditismo Por Uma Questa', 1, 'Da Lama Ao Caos')
# ('Banditismo Por Uma Questa', 1, 'Da Lama Ao Caos')
# ('Rios Pontes & Overdrives', 1, 'Da Lama Ao Caos')
# ('Samba Makossa', 1, 'Da Lama Ao Caos')
# ('Da Lama Ao Caos', 1, 'Da Lama Ao Caos')
# ('Maracatu De Tiro Certeiro', 1, 'Da Lama Ao Caos')
# ('Computadores Fazem Arte', 1, 'Da Lama Ao Caos')
# ('Soldado Da Paz', 1, 'Acústico MTV [Live]')
# ('Firmamento', 1, 'Acústico MTV [Live]')
# ('Extra', 1, 'Acústico MTV [Live]')
# ('Podes Crer', 1, 'Acústico MTV [Live]')
# ('Já Foi', 1, 'Acústico MTV [Live]')
# ('Onde Você Mora?', 1, 'Acústico MTV [Live]')
# ('Pensamento', 1, 'Acústico MTV [Live]')
# ('Onde Você Mora?', 1, 'Cidade Negra - Hits')
# ('Falar A Verdade', 1, 'Cidade Negra - Hits')
# ('Firmamento', 1, 'Cidade Negra - Hits')
# ('Doutor', 1, 'Cidade Negra - Hits')
# ('Na Frente Da TV', 1, 'Cidade Negra - Hits')
# ('Sábado A Noite', 1, 'Cidade Negra - Hits')
# ('Eu Também Quero Beijar', 1, 'Cidade Negra - Hits')
# ('Amor Demais', 1, 'Na Pista')
# ('Felicidade Urgente', 1, 'Na Pista')
# ('Livre Pra Viver', 1, 'Na Pista')
# ('TriboTchan', 1, 'Axé Bahia 2001')
# ('Tapa Aqui, Descobre Ali', 1, 'Axé Bahia 2001')
# ('Levada do Amor (Ailoviu)', 1, 'Axé Bahia 2001')
# ('Lavadeira', 1, 'Axé Bahia 2001')
# ('Reggae Tchan', 1, 'Axé Bahia 2001')
# ('My Love', 1, 'Axé Bahia 2001')
# ('Communication Breakdown', 1, 'BBC Sessions [Disc 1] [Live]')
# ('Dazed and Confused', 1, 'BBC Sessions [Disc 1] [Live]')
# ('Communication Breakdown(2)', 1, 'BBC Sessions [Disc 1] [Live]')
# ('Travelling Riverside Blues', 1, 'BBC Sessions [Disc 1] [Live]')
# ("I Can't Quit You Baby(2)", 1, 'BBC Sessions [Disc 1] [Live]')
# ('You Shook Me(2)', 1, 'BBC Sessions [Disc 1] [Live]')
# ('Carolina Hard-Core Ecstasy', 1, 'Bongo Fury')
# ('Sam With The Showing Scalp Flat Top', 1, 'Bongo Fury')
# ('Advance Romance', 1, 'Bongo Fury')
# ('Man With The Woman Head', 1, 'Bongo Fury')
# ('X-9 2001', 1, 'Carnaval 2001')
# ('Gavioes 2001', 1, 'Carnaval 2001')
# ('Camisa Verde 2001', 1, 'Carnaval 2001')
# ('Leandro De Itaquera 2001', 1, 'Carnaval 2001')
# ('Ipiranga 2001', 1, 'Carnaval 2001')
# ('Morro Da Casa Verde 2001', 1, 'Carnaval 2001')
# ('Mas Que Nada', 1, 'Chill: Brazil (Disc 1)')
# ('Vôo Sobre o Horizonte', 1, 'Chill: Brazil (Disc 1)')
# ('Água de Beber', 1, 'Chill: Brazil (Disc 1)')
# ('Samba da Bençaco', 1, 'Chill: Brazil (Disc 1)')
# ('Mistério da Raça', 1, 'Chill: Brazil (Disc 1)')
# ('All Star', 1, 'Chill: Brazil (Disc 1)')
# ('Maria Fumaça', 1, 'Chill: Brazil (Disc 1)')
# ('Eu Vim Da Bahia - Live', 1, 'Chill: Brazil (Disc 2)')
# ('Linha Do Horizonte', 1, 'Chill: Brazil (Disc 2)')
# ('Only A Dream In Rio', 1, 'Chill: Brazil (Disc 2)')
# ('Abrir A Porta', 1, 'Chill: Brazil (Disc 2)')
# ('Momentos Que Marcam', 1, 'Chill: Brazil (Disc 2)')
# ('Um Jantar Pra Dois', 1, 'Chill: Brazil (Disc 2)')
# ('Santo Antonio', 1, 'Chill: Brazil (Disc 2)')
# ('Turn The Page', 1, 'Garage Inc. (Disc 1)')
# ('Die Die My Darling', 1, 'Garage Inc. (Disc 1)')
# ('Astronomy', 1, 'Garage Inc. (Disc 1)')
# ("Tuesday's Gone", 1, 'Garage Inc. (Disc 1)')
# ('The More I See', 1, 'Garage Inc. (Disc 1)')
# ('A Kind Of Magic', 1, 'Greatest Hits II')
# ('Under Pressure', 1, 'Greatest Hits II')
# ('Radio GA GA', 1, 'Greatest Hits II')
# ('I Want It All', 1, 'Greatest Hits II')
# ('I Want To Break Free', 1, 'Greatest Hits II')
# ('Innuendo', 1, 'Greatest Hits II')
# ("It's A Hard Life", 1, 'Greatest Hits II')
# ('Breakthru', 1, 'Greatest Hits II')
# ('Who Wants To Live Forever', 1, 'Greatest Hits II')
# ('Headlong', 1, 'Greatest Hits II')
# ('The Invisible Man', 1, 'Greatest Hits II')
# ('The Show Must Go On', 1, 'Greatest Hits II')
# ('Black Diamond', 1, 'Greatest Kiss')
# ('Hard Luck Woman', 1, 'Greatest Kiss')
# ('Love Gun', 1, 'Greatest Kiss')
# ('Deuce', 1, 'Greatest Kiss')
# ("Goin' Blind", 1, 'Greatest Kiss')
# ('She', 1, 'Greatest Kiss')
# ('I Was Made For Loving You', 1, 'Greatest Kiss')
# ('Shout It Out Loud', 1, 'Greatest Kiss')
# ('God Of Thunder', 1, 'Greatest Kiss')
# ('Beth', 1, 'Greatest Kiss')
# ('Strutter', 1, 'Greatest Kiss')
# ('Cold Gin', 1, 'Greatest Kiss')
# ('Plaster Caster', 1, 'Greatest Kiss')
# ("God Gave Rock 'n' Roll To You", 1, 'Greatest Kiss')
# ('De La Luz', 1, 'Heart of the Night')
# ('Playtime', 1, 'Heart of the Night')
# ("Valentino's", 1, 'Heart of the Night')
# ('Believe', 1, 'Heart of the Night')
# ('As We Sleep', 1, 'Heart of the Night')
# ('When Evening Falls', 1, 'Heart of the Night')
# ('Best Thing', 1, 'Heart of the Night')
# ('Maria', 1, 'International Superhits')
# ('Poprocks And Coke', 1, 'International Superhits')
# ('Longview', 1, 'International Superhits')
# ('She', 1, 'International Superhits')
# ('Geek Stink Breath', 1, 'International Superhits')
# ('Brain Stew', 1, 'International Superhits')
# ('Jaded', 1, 'International Superhits')
# ('Walking Contradiction', 1, 'International Superhits')
# ('Stuck With Me', 1, 'International Superhits')
# ('Redundant', 1, 'International Superhits')
# ('Minority', 1, 'International Superhits')
# ("Macy's Day Parade", 1, 'International Superhits')
# ('Into The Light', 1, 'Into The Light')
# ('River Song', 1, 'Into The Light')
# ("Don't You Cry", 1, 'Into The Light')
# ('Slave', 1, 'Into The Light')
# ('Cry For Love', 1, 'Into The Light')
# ('Wherever You May Go', 1, 'Into The Light')
# ('Grito De Alerta', 1, 'Meus Momentos')
# ('Não Dá Mais Pra Segurar (Explode Coração)', 1, 'Meus Momentos')
# ('Começaria Tudo Outra Vez', 1, 'Meus Momentos')
# ('Diga Lá, Coração', 1, 'Meus Momentos')
# ('Lindo Lago Do Amor', 1, 'Meus Momentos')
# ('Eu Apenas Queria Que Voçê Soubesse', 1, 'Meus Momentos')
# ('Ponto De Interrogação', 1, 'Meus Momentos')
# ('Um Indio', 1, 'Minha Historia')
# ('Podres Poderes', 1, 'Minha Historia')
# ('Voce Nao Entende Nada - Cotidiano', 1, 'Minha Historia')
# ('Menino Do Rio', 1, 'Minha Historia')
# ('Queixa', 1, 'Minha Historia')
# ('O Leaozinho', 1, 'Minha Historia')
# ('Fora Da Ordem', 1, 'Minha Historia')
# ('Top Top', 1, 'Minha História')
# ('Chão De Estrelas', 1, 'Minha História')
# ('Vida De Cachorro', 1, 'Minha História')
# ('Rita Lee', 1, 'Minha História')
# ('Posso Perder Minha Mulher, Minha Mãe, Desde Que Eu Tenha O Rock And Roll', 1, 'Minha História')
# ('Meu Refrigerador Não Funciona', 1, 'Minha História')
# ('Stormbringer', 1, 'MK III The Final Concerts [Disc 1]')
# ('You Fool No One', 1, 'MK III The Final Concerts [Disc 1]')
# ('Houses Of The Holy', 1, 'Physical Graffiti [Disc 1]')
# ('Trampled Under Foot', 1, 'Physical Graffiti [Disc 1]')
# ('Beija-Flor', 1, 'Sambas De Enredo 2001')
# ('Viradouro', 1, 'Sambas De Enredo 2001')
# ('Mangueira', 1, 'Sambas De Enredo 2001')
# ('União Da Ilha', 1, 'Sambas De Enredo 2001')
# ('Caprichosos', 1, 'Sambas De Enredo 2001')
# ('Tradição', 1, 'Sambas De Enredo 2001')
# ('Love Of My Life', 1, 'Supernatural')
# ('Put Your Lights On', 1, 'Supernatural')
# ('Do You Like The Way', 1, 'Supernatural')
# ('Maria Maria', 1, 'Supernatural')
# ('El Farol', 1, 'Supernatural')
# ('Primavera', 1, 'Supernatural')
# ('Manuel', 1, 'The Best of Ed Motta')
# ('Entre E Ouça', 1, 'The Best of Ed Motta')
# ('Um Love', 1, 'The Best of Ed Motta')
# ('Seis Da Tarde', 1, 'The Best of Ed Motta')
# ('Do You Have Other Loves?', 1, 'The Best of Ed Motta')
# ('Agora Que O Dia Acordou', 1, 'The Best of Ed Motta')
# ('Jeru', 1, 'The Essential Miles Davis [Disc 1]')
# ('Compulsion', 1, 'The Essential Miles Davis [Disc 1]')
# ("'Round Midnight", 1, 'The Essential Miles Davis [Disc 1]')
# ('Bye Bye Blackbird', 1, 'The Essential Miles Davis [Disc 1]')
# ('So What', 1, 'The Essential Miles Davis [Disc 1]')
# ('The Pan Piper', 1, 'The Essential Miles Davis [Disc 1]')
# ('E.S.P.', 1, 'The Essential Miles Davis [Disc 2]')
# ('Nefertiti', 1, 'The Essential Miles Davis [Disc 2]')
# ('Black Satin', 1, 'The Essential Miles Davis [Disc 2]')
# ('Jean Pierre (Live)', 1, 'The Essential Miles Davis [Disc 2]')
# ('Going Down / Highway Star', 1, 'The Final Concerts (Disc 2)')
# ('Let Me Off Uptown', 1, "Up An' Atom")
# ('Opus No.1', 1, "Up An' Atom")
# ('Boogie Blues', 1, "Up An' Atom")
# ('How High The Moon', 1, "Up An' Atom")
# ("Up An' Atom", 1, "Up An' Atom")
# ('Bop Boogie', 1, "Up An' Atom")
# ('Overtime', 1, "Up An' Atom")
# ('Jungle Drums', 1, "Up An' Atom")
# ('Showcase', 1, "Up An' Atom")
# ('Pot-Pourri N.º 4', 1, 'Vinícius De Moraes - Sem Limite')
# ('Samba Da Volta', 1, 'Vinícius De Moraes - Sem Limite')
# ('Canto De Ossanha', 1, 'Vinícius De Moraes - Sem Limite')
# ('Pot-Pourri N.º 5', 1, 'Vinícius De Moraes - Sem Limite')
# ('Formosa', 1, 'Vinícius De Moraes - Sem Limite')
# ('Como É Duro Trabalhar', 1, 'Vinícius De Moraes - Sem Limite')
# ('Minha Namorada', 1, 'Vinícius De Moraes - Sem Limite')
# ('Por Que Será', 1, 'Vinícius De Moraes - Sem Limite')
# ('Berimbau', 1, 'Vinícius De Moraes - Sem Limite')
# ('Deixa', 1, 'Vinícius De Moraes - Sem Limite')
# ('Pot-Pourri N.º 2', 1, 'Vinícius De Moraes - Sem Limite')
# ('Samba Em Prelúdio', 1, 'Vinícius De Moraes - Sem Limite')
# ('Carta Ao Tom 74', 1, 'Vinícius De Moraes - Sem Limite')
# ('Chão de Giz (Elba Ramalho)', 1, 'Vozes do MPB')
# ('Coração do Agreste (Fafá de Belém)', 1, 'Vozes do MPB')
# ('Caçador de Mim (Sá & Guarabyra)', 1, 'Vozes do MPB')
# ('Romaria (Renato Teixeira)', 1, 'Vozes do MPB')
# ('Wave (Os Cariocas)', 1, 'Vozes do MPB')
# ('Garota de Ipanema (Dick Farney)', 1, 'Vozes do MPB')
# ('Preciso Apender a Viver Só (Maysa)', 1, 'Vozes do MPB')
# ('Proud Mary', 1, 'Chronicle, Vol. 1')
# ('Bad Moon Rising', 1, 'Chronicle, Vol. 1')
# ('Lodi', 1, 'Chronicle, Vol. 1')
# ('Green River', 1, 'Chronicle, Vol. 1')
# ('Down On The Corner', 1, 'Chronicle, Vol. 1')
# ('Fortunate Son', 1, 'Chronicle, Vol. 1')
# ("Who'll Stop The Rain", 1, 'Chronicle, Vol. 1')
# ('Up Around The Bend', 1, 'Chronicle, Vol. 1')
# ('Run Through The Jungle', 1, 'Chronicle, Vol. 1')
# ('Long As I Can See The Light', 1, 'Chronicle, Vol. 1')
# ('Hey Tonight', 1, 'Chronicle, Vol. 1')
# ('Someday Never Comes', 1, 'Chronicle, Vol. 1')
# ('Walking On The Water', 1, 'Chronicle, Vol. 2')
# ('Suzie-Q, Pt. 2', 1, 'Chronicle, Vol. 2')
# ('Born On The Bayou', 1, 'Chronicle, Vol. 2')
# ('Tombstone Shadow', 1, 'Chronicle, Vol. 2')
# ('Wrote A Song For Everyone', 1, 'Chronicle, Vol. 2')
# ('Night Time Is The Right Time', 1, 'Chronicle, Vol. 2')
# ('Cotton Fields', 1, 'Chronicle, Vol. 2')
# ('Before You Accuse Me', 1, 'Chronicle, Vol. 2')
# ('Pagan Baby', 1, 'Chronicle, Vol. 2')
# ('(Wish I Could) Hideaway', 1, 'Chronicle, Vol. 2')
# ("It's Just A Thought", 1, 'Chronicle, Vol. 2')
# ('Molina', 1, 'Chronicle, Vol. 2')
# ('Born To Move', 1, 'Chronicle, Vol. 2')
# ('Gatas Extraordinárias', 1, 'Cássia Eller - Coleção Sem Limite [Disc 2]')
# ('Eu Sou Neguinha (Ao Vivo)', 1, 'Cássia Eller - Coleção Sem Limite [Disc 2]')
# ('Coroné Antonio Bento', 1, 'Cássia Eller - Coleção Sem Limite [Disc 2]')
# ('Você Passa, Eu Acho Graça (Ao Vivo)', 1, 'Cássia Eller - Coleção Sem Limite [Disc 2]')
# ('Meu Mundo Fica Completo (Com Você)', 1, 'Cássia Eller - Coleção Sem Limite [Disc 2]')
# ('Música Urbana 2', 1, 'Cássia Eller - Coleção Sem Limite [Disc 2]')
# ('Palavras Ao Vento', 1, 'Cássia Eller - Coleção Sem Limite [Disc 2]')
# ('Não Sei O Que Eu Quero Da Vida', 1, 'Cássia Eller - Coleção Sem Limite [Disc 2]')
# ('Smells Like Teen Spirit (Ao Vivo)', 1, 'Cássia Eller - Sem Limite [Disc 1]')
# ('E.C.T.', 1, 'Cássia Eller - Sem Limite [Disc 1]')
# ('Todo Amor Que Houver Nesta Vida', 1, 'Cássia Eller - Sem Limite [Disc 1]')
# ('Metrô. Linha 743', 1, 'Cássia Eller - Sem Limite [Disc 1]')
# ('Admirável Gado Novo', 1, 'Cássia Eller - Sem Limite [Disc 1]')
# ('Eleanor Rigby', 1, 'Cássia Eller - Sem Limite [Disc 1]')
# ('Socorro', 1, 'Cássia Eller - Sem Limite [Disc 1]')
# ("Comin' Home", 1, 'Come Taste The Band')
# ('I Need Love', 1, 'Come Taste The Band')
# ('Drifter', 1, 'Come Taste The Band')
# ('Love Child', 1, 'Come Taste The Band')
# ('You Keep On Moving', 1, 'Come Taste The Band')
# ('Child In Time', 1, 'Deep Purple In Rock')
# ('Flight Of The Rat', 1, 'Deep Purple In Rock')
# ('Into The Fire', 1, 'Deep Purple In Rock')
# ('Strange Kind Of Woman', 1, 'Fireball')
# ('No One Came', 1, 'Fireball')
# ('Knocking At Your Back Door', 1, "Knocking at Your Back Door: The Best Of Deep Purple in the 80's")
# ("Nobody's Home", 1, "Knocking at Your Back Door: The Best Of Deep Purple in the 80's")
# ('Black Night', 1, "Knocking at Your Back Door: The Best Of Deep Purple in the 80's")
# ('The Unwritten Law', 1, "Knocking at Your Back Door: The Best Of Deep Purple in the 80's")
# ('Hush', 1, "Knocking at Your Back Door: The Best Of Deep Purple in the 80's")
# ('Pictures Of Home', 1, 'Machine Head')
# ("Space Truckin'", 1, 'Machine Head')
# ('Vavoom : Ted The Mechanic', 1, 'Purpendicular')
# ('Sometimes I Feel Like Screaming', 1, 'Purpendicular')
# ("Cascades : I'm Not Your Lover", 1, 'Purpendicular')
# ('A Touch Away', 1, 'Purpendicular')
# ('Hey Cisco', 1, 'Purpendicular')
# ('King Of Dreams', 1, 'Slaves And Masters')
# ('The Cut Runs Deep', 1, 'Slaves And Masters')
# ('Love Conquers All', 1, 'Slaves And Masters')
# ('Fortuneteller', 1, 'Slaves And Masters')
# ('Stormbringer', 1, 'Stormbringer')
# ("Love Don't Mean a Thing", 1, 'Stormbringer')
# ("You Can't Do it Right (With the One You Love)", 1, 'Stormbringer')
# ('High Ball Shooter', 1, 'Stormbringer')
# ('The Battle Rages On', 1, 'The Battle Rages On')
# ('Lick It Up', 1, 'The Battle Rages On')
# ('Ramshackle Man', 1, 'The Battle Rages On')
# ('A Twist In The Tail', 1, 'The Battle Rages On')
# ("One Man's Meat", 1, 'The Battle Rages On')
# ('Pour Some Sugar On Me', 1, "Vault: Def Leppard's Greatest Hits")
# ('Two Steps Behind [Acoustic Version]', 1, "Vault: Def Leppard's Greatest Hits")
# ('Animal', 1, "Vault: Def Leppard's Greatest Hits")
# ('When Love & Hate Collide', 1, "Vault: Def Leppard's Greatest Hits")
# ('Action', 1, "Vault: Def Leppard's Greatest Hits")
# ('Rock Of Ages', 1, "Vault: Def Leppard's Greatest Hits")
# ('Hysteria', 1, "Vault: Def Leppard's Greatest Hits")
# ('Otay', 1, 'Outbreak')
# ('Groovus Interruptus', 1, 'Outbreak')
# ('Outbreak', 1, 'Outbreak')
# ('Baltimore, DC', 1, 'Outbreak')
# ('Cigano', 1, 'Djavan Ao Vivo - Vol. 02')
# ('Se...', 1, 'Djavan Ao Vivo - Vol. 02')
# ('Lilás', 1, 'Djavan Ao Vivo - Vol. 02')
# ('Acelerou', 1, 'Djavan Ao Vivo - Vol. 02')
# ('Um Amor Puro', 1, 'Djavan Ao Vivo - Vol. 02')
# ('Nem Um Dia', 1, 'Djavan Ao Vivo - Vol. 1')
# ('Oceano', 1, 'Djavan Ao Vivo - Vol. 1')
# ('Flor De Lis', 1, 'Djavan Ao Vivo - Vol. 1')
# ('Acelerou', 1, 'Djavan Ao Vivo - Vol. 1')
# ('Um Amor Puro', 1, 'Djavan Ao Vivo - Vol. 1')
# ('Atrás da Porta', 1, 'Elis Regina-Minha História')
# ('Casa no Campo', 1, 'Elis Regina-Minha História')
# ('Romaria', 1, 'Elis Regina-Minha História')
# ('Alô, Alô, Marciano', 1, 'Elis Regina-Minha História')
# ('Me Deixas Louca', 1, 'Elis Regina-Minha História')
# ('Fascinação', 1, 'Elis Regina-Minha História')
# ('Saudosa Maloca', 1, 'Elis Regina-Minha História')
# ('As Aparências Enganam', 1, 'Elis Regina-Minha História')
# ('Madalena', 1, 'Elis Regina-Minha História')
# ('Maria Rosa', 1, 'Elis Regina-Minha História')
# ('Aprendendo A Jogar', 1, 'Elis Regina-Minha História')
# ('Layla', 1, 'The Cream Of Clapton')
# ('Badge', 1, 'The Cream Of Clapton')
# ('Crossroads', 1, 'The Cream Of Clapton')
# ('Bell Bottom Blues', 1, 'The Cream Of Clapton')
# ('After Midnight', 1, 'The Cream Of Clapton')
# ('Swing Low Sweet Chariot', 1, 'The Cream Of Clapton')
# ('Knockin On Heavens Door', 1, 'The Cream Of Clapton')
# ('Wonderful Tonight', 1, 'The Cream Of Clapton')
# ('Let It Grow', 1, 'The Cream Of Clapton')
# ('Signe', 1, 'Unplugged')
# ('Before You Accuse Me', 1, 'Unplugged')
# ('Hey Hey', 1, 'Unplugged')
# ('Tears In Heaven', 1, 'Unplugged')
# ("Nobody Knows You When You're Down & Out", 1, 'Unplugged')
# ('Layla', 1, 'Unplugged')
# ("Walkin' Blues", 1, 'Unplugged')
# ('Alberta', 1, 'Unplugged')
# ('San Francisco Bay Blues', 1, 'Unplugged')
# ('Old Love', 1, 'Unplugged')
# ('Stripsearch', 1, 'Album Of The Year')
# ('Naked In Front Of The Computer', 1, 'Album Of The Year')
# ('Helpless', 1, 'Album Of The Year')
# ('Mouth To Mouth', 1, 'Album Of The Year')
# ('Ashes To Ashes', 1, 'Album Of The Year')
# ('Got That Feeling', 1, 'Album Of The Year')
# ('Paths Of Glory', 1, 'Album Of The Year')
# ('Home Sick Home', 1, 'Album Of The Year')
# ('Pristina', 1, 'Album Of The Year')
# ('RV', 1, 'Angel Dust')
# ("Everything's Ruined", 1, 'Angel Dust')
# ('Malpractice', 1, 'Angel Dust')
# ('Kindergarten', 1, 'Angel Dust')
# ('Be Aggressive', 1, 'Angel Dust')
# ('A Small Victory', 1, 'Angel Dust')
# ('Midnight Cowboy', 1, 'Angel Dust')
# ('Get Out', 1, 'King For A Day Fool For A Lifetime')
# ('The Gentle Art Of Making Enemies', 1, 'King For A Day Fool For A Lifetime')
# ('Star A.D.', 1, 'King For A Day Fool For A Lifetime')
# ('Cuckoo For Caca', 1, 'King For A Day Fool For A Lifetime')
# ('Ugly In The Morning', 1, 'King For A Day Fool For A Lifetime')
# ('Take This Bottle', 1, 'King For A Day Fool For A Lifetime')
# ('King For A Day', 1, 'King For A Day Fool For A Lifetime')
# ('From Out Of Nowhere', 1, 'The Real Thing')
# ('Epic', 1, 'The Real Thing')
# ('Falling To Pieces', 1, 'The Real Thing')
# ("Surprise! You're Dead!", 1, 'The Real Thing')
# ('Underwater Love', 1, 'The Real Thing')
# ('The Morning After', 1, 'The Real Thing')
# ('Woodpecker From Mars', 1, 'The Real Thing')
# ('Xote Dos Milagres', 1, 'Deixa Entrar')
# ('Zeca Violeiro', 1, 'Deixa Entrar')
# ('Avisa', 1, 'Deixa Entrar')
# ('Principiando/Decolagem', 1, 'Deixa Entrar')
# ('Medo De Escuro', 1, 'Deixa Entrar')
# ('Desaforo', 1, 'Deixa Entrar')
# ('In Your Honor', 1, 'In Your Honor [Disc 1]')
# ('No Way Back', 1, 'In Your Honor [Disc 1]')
# ('Free Me', 1, 'In Your Honor [Disc 1]')
# ('Still', 1, 'In Your Honor [Disc 2]')
# ('What If I Do?', 1, 'In Your Honor [Disc 2]')
# ('Friend Of A Friend', 1, 'In Your Honor [Disc 2]')
# ('Over And Out', 1, 'In Your Honor [Disc 2]')
# ('Virginia Moon', 1, 'In Your Honor [Disc 2]')
# ('Razor', 1, 'In Your Honor [Disc 2]')
# ('Disenchanted Lullaby', 1, 'One By One')
# ('Overdrive', 1, 'One By One')
# ('Burn Away', 1, 'One By One')
# ('Monkey Wrench', 1, 'The Colour And The Shape')
# ('Hey, Johnny Park!', 1, 'The Colour And The Shape')
# ('My Hero', 1, 'The Colour And The Shape')
# ('See You', 1, 'The Colour And The Shape')
# ('Everlong', 1, 'The Colour And The Shape')
# ('Walking After You', 1, 'The Colour And The Shape')
# ('New York, New York', 1, 'My Way: The Best Of Frank Sinatra [Disc 1]')
# ('I Get A Kick Out Of You', 1, 'My Way: The Best Of Frank Sinatra [Disc 1]')
# ('What Now My Love', 1, 'My Way: The Best Of Frank Sinatra [Disc 1]')
# ('Summer Love', 1, 'My Way: The Best Of Frank Sinatra [Disc 1]')
# ('My Kind Of Town', 1, 'My Way: The Best Of Frank Sinatra [Disc 1]')
# ('Fly Me To The Moon', 1, 'My Way: The Best Of Frank Sinatra [Disc 1]')
# ('It Was A Very Good Year', 1, 'My Way: The Best Of Frank Sinatra [Disc 1]')
# ('Come Fly With Me', 1, 'My Way: The Best Of Frank Sinatra [Disc 1]')
# ('Bad, Bad Leroy Brown', 1, 'My Way: The Best Of Frank Sinatra [Disc 1]')
# ('Mack The Knife', 1, 'My Way: The Best Of Frank Sinatra [Disc 1]')
# ('Entrando Na Sua (Intro)', 1, 'Roda De Funk')
# ('Nervosa', 1, 'Roda De Funk')
# ('Zambação', 1, 'Roda De Funk')
# ('Funk Hum', 1, 'Roda De Funk')
# ('Dujji', 1, 'Roda De Funk')
# ('Meu Guarda-Chuva', 1, 'Roda De Funk')
# ('Divirta-Se (Saindo Da Sua)', 1, 'Roda De Funk')
# ('Forty Days Instrumental', 1, 'Roda De Funk')
# ('Esperando Na Janela', 1, 'As Canções de Eu Tu Eles')
# ('Juazeiro', 1, 'As Canções de Eu Tu Eles')
# ('Assum Preto', 1, 'As Canções de Eu Tu Eles')
# ('Pau-De-Arara', 1, 'As Canções de Eu Tu Eles')
# ('Lamento Sertanejo', 1, 'As Canções de Eu Tu Eles')
# ('Refavela (Live)', 1, 'Quanta Gente Veio Ver (Live)')
# ('Quanta (Live)', 1, 'Quanta Gente Veio Ver (Live)')
# ('Estrela (Live)', 1, 'Quanta Gente Veio Ver (Live)')
# ('Pela Internet (Live)', 1, 'Quanta Gente Veio Ver (Live)')
# ('Opachorô (Live)', 1, 'Quanta Gente Veio Ver (Live)')
# ('Copacabana (Live)', 1, 'Quanta Gente Veio Ver (Live)')
# ('De Ouro E Marfim (Live)', 1, 'Quanta Gente Veio Ver (Live)')
# ('Refazenda', 1, 'Unplugged')
# ('Realce', 1, 'Unplugged')
# ('A Paz', 1, 'Unplugged')
# ('Sampa', 1, 'Unplugged')
# ('Parabolicamará', 1, 'Unplugged')
# ('Tempo Rei', 1, 'Unplugged')
# ('Expresso 2222', 1, 'Unplugged')
# ('Aquele Abraço', 1, 'Unplugged')
# ('Palco', 1, 'Unplugged')
# ('Toda Menina Baiana', 1, 'Unplugged')
# ('Sítio Do Pica-Pau Amarelo', 1, 'Unplugged')
# ('Straight Out Of Line', 1, 'Faceless')
# ('Faceless', 1, 'Faceless')
# ('Changes', 1, 'Faceless')
# ('Make Me Believe', 1, 'Faceless')
# ('I Fucking Hate You', 1, 'Faceless')
# ('I Am', 1, 'Faceless')
# ('American Idiot', 1, 'American Idiot')
# ("Jesus Of Suburbia / City Of The Damned / I Don't Care / Dearly Beloved / Tales Of Another Broken Home", 1, 'American Idiot')
# ('Boulevard Of Broken Dreams', 1, 'American Idiot')
# ('Are We The Waiting', 1, 'American Idiot')
# ('St. Jimmy', 1, 'American Idiot')
# ('Extraordinary Girl', 1, 'American Idiot')
# ('Letterbomb', 1, 'American Idiot')
# ('Wake Me Up When September Ends', 1, 'American Idiot')
# ("Homecoming / The Death Of St. Jimmy / East 12th St. / Nobody Likes You / Rock And Roll Girlfriend / We're Coming Home Again", 1, 'American Idiot')
# ('Welcome to the Jungle', 1, 'Appetite for Destruction')
# ("It's So Easy", 1, 'Appetite for Destruction')
# ('Out Ta Get Me', 1, 'Appetite for Destruction')
# ('Mr. Brownstone', 1, 'Appetite for Destruction')
# ('Paradise City', 1, 'Appetite for Destruction')
# ('Think About You', 1, 'Appetite for Destruction')
# ('Anything Goes', 1, 'Appetite for Destruction')
# ('Right Next Door to Hell', 1, 'Use Your Illusion I')
# ("Dust N' Bones", 1, 'Use Your Illusion I')
# ('Live and Let Die', 1, 'Use Your Illusion I')
# ("Don't Cry (Original)", 1, 'Use Your Illusion I')
# ("You Ain't the First", 1, 'Use Your Illusion I')
# ('Bad Obsession', 1, 'Use Your Illusion I')
# ('Back off Bitch', 1, 'Use Your Illusion I')
# ("Double Talkin' Jive", 1, 'Use Your Illusion I')
# ("Don't Damn Me", 1, 'Use Your Illusion I')
# ('Dead Horse', 1, 'Use Your Illusion I')
# ('Coma', 1, 'Use Your Illusion I')
# ('Civil War', 1, 'Use Your Illusion II')
# ('14 Years', 1, 'Use Your Illusion II')
# ('Yesterdays', 1, 'Use Your Illusion II')
# ('Shotgun Blues', 1, 'Use Your Illusion II')
# ('Pretty Tied Up', 1, 'Use Your Illusion II')
# ('Estranged', 1, 'Use Your Illusion II')
# ('You Could Be Mine', 1, 'Use Your Illusion II')
# ("Don't Cry", 1, 'Use Your Illusion II')
# ('Colibri', 1, 'Blue Moods')
# ('Magnetic Ocean', 1, 'Blue Moods')
# ('Deep Waters', 1, 'Blue Moods')
# ('Millenium', 1, 'Blue Moods')
# ("Thinking 'Bout Tomorrow", 1, 'Blue Moods')
# ("Jacob's Ladder", 1, 'Blue Moods')
# ('She Wears Black', 1, 'Blue Moods')
# ("These Colours Don't Run", 1, 'A Matter of Life and Death')
# ('Brighter Than a Thousand Suns', 1, 'A Matter of Life and Death')
# ('The Pilgrim', 1, 'A Matter of Life and Death')
# ('Lord of Light', 1, 'A Matter of Life and Death')
# ('The Trooper', 1, 'A Real Dead One')
# ('Prowler', 1, 'A Real Dead One')
# ('Transylvania', 1, 'A Real Dead One')
# ('Where Eagles Dare', 1, 'A Real Dead One')
# ('Run To The Hilss', 1, 'A Real Dead One')
# ('2 Minutes To Midnight', 1, 'A Real Dead One')
# ('Iron Maiden', 1, 'A Real Dead One')
# ('Wasting Love', 1, 'A Real Live One')
# ('Bring Your Daughter... To The Slaughter', 1, 'A Real Live One')
# ('Heaven Can Wait', 1, 'A Real Live One')
# ('The Wicker Man', 1, 'Brave New World')
# ('Ghost Of The Navigator', 1, 'Brave New World')
# ('Blood Brothers', 1, 'Brave New World')
# ('Dream Of Mirrors', 1, 'Brave New World')
# ('Wildest Dreams', 1, 'Dance Of Death')
# ('Dance Of Death', 1, 'Dance Of Death')
# ('Gates Of Tomorrow', 1, 'Dance Of Death')
# ('Face In The Sand', 1, 'Dance Of Death')
# ('Age Of Innocence', 1, 'Dance Of Death')
# ('Afraid To Shoot Strangers', 1, 'Fear Of The Dark')
# ('Fear Is The Key', 1, 'Fear Of The Dark')
# ('The Fugitive', 1, 'Fear Of The Dark')
# ('Chains Of Misery', 1, 'Fear Of The Dark')
# ('Fear Of The Dark', 1, 'Fear Of The Dark')
# ('01 - Prowler', 1, 'Iron Maiden')
# ('04 - Running Free', 1, 'Iron Maiden')
# ('05 - Phantom of the Opera', 1, 'Iron Maiden')
# ('09 - Iron Maiden', 1, 'Iron Maiden')
# ('The Ides Of March', 1, 'Killers')
# ('Another Life', 1, 'Killers')
# ('Genghis Khan', 1, 'Killers')
# ('Purgatory', 1, 'Killers')
# ('Drifter', 1, 'Killers')
# ('2 Minutes To Midnight', 1, 'Live After Death')
# ('The Trooper', 1, 'Live After Death')
# ('Powerslave', 1, 'Live After Death')
# ('The Number Of The Beast', 1, 'Live After Death')
# ('Run To The Hills', 1, 'Live After Death')
# ('Running Free', 1, 'Live After Death')
# ('Die With Your Boots On', 1, 'Live After Death')
# ('Phantom Of The Opera', 1, 'Live After Death')
# ('Wrathchild', 1, 'Live At Donington 1992 (Disc 1)')
# ('From Here To Eternity', 1, 'Live At Donington 1992 (Disc 1)')
# ('The Evil That Men Do', 1, 'Live At Donington 1992 (Disc 1)')
# ('Afraid To Shoot Strangers', 1, 'Live At Donington 1992 (Disc 1)')
# ('Heaven Can Wait', 1, 'Live At Donington 1992 (Disc 2)')
# ('Sanctuary', 1, 'Live At Donington 1992 (Disc 2)')
# ('Tailgunner', 1, 'No Prayer For The Dying')
# ('Holy Smoke', 1, 'No Prayer For The Dying')
# ('No Prayer For The Dying', 1, 'No Prayer For The Dying')
# ('Fates Warning', 1, 'No Prayer For The Dying')
# ('The Assassin', 1, 'No Prayer For The Dying')
# ('Bring Your Daughter... ...To The Slaughter', 1, 'No Prayer For The Dying')
# ('The Trooper', 1, 'Piece Of Mind')
# ('Still Life', 1, 'Piece Of Mind')
# ('To Tame A Land', 1, 'Piece Of Mind')
# ('2 Minutes To Midnight', 1, 'Powerslave')
# ('Losfer Words', 1, 'Powerslave')
# ('Flash of The Blade', 1, 'Powerslave')
# ('Duelists', 1, 'Powerslave')
# ('Back in the Village', 1, 'Powerslave')
# ('Powerslave', 1, 'Powerslave')
# ('Rime of the Ancient Mariner', 1, 'Powerslave')
# ('Intro', 1, 'Rock In Rio [CD1]')
# ('The Wicker Man', 1, 'Rock In Rio [CD1]')
# ('Ghost Of The Navigator', 1, 'Rock In Rio [CD1]')
# ('Brave New World', 1, 'Rock In Rio [CD1]')
# ('Wrathchild', 1, 'Rock In Rio [CD1]')
# ('Sign Of The Cross', 1, 'Rock In Rio [CD1]')
# ('Dream Of Mirrors', 1, 'Rock In Rio [CD2]')
# ('Fear Of The Dark', 1, 'Rock In Rio [CD2]')
# ('Iron Maiden', 1, 'Rock In Rio [CD2]')
# ('Hallowed Be Thy Name', 1, 'Rock In Rio [CD2]')
# ('Sanctuary', 1, 'Rock In Rio [CD2]')
# ('Run To The Hills', 1, 'Rock In Rio [CD2]')
# ('Can I Play With Madness', 1, 'Seventh Son of a Seventh Son')
# ('The Evil That Men Do', 1, 'Seventh Son of a Seventh Son')
# ('Seventh Son of a Seventh Son', 1, 'Seventh Son of a Seventh Son')
# ('The Prophecy', 1, 'Seventh Son of a Seventh Son')
# ('Only the Good Die Young', 1, 'Seventh Son of a Seventh Son')
# ('Caught Somewhere in Time', 1, 'Somewhere in Time')
# ('Sea of Madness', 1, 'Somewhere in Time')
# ('Heaven Can Wait', 1, 'Somewhere in Time')
# ('Stranger in a Strange Land', 1, 'Somewhere in Time')
# ('De Ja Vu', 1, 'Somewhere in Time')
# ('Children of the Damned', 1, 'The Number of The Beast')
# ('Hallowed Be Thy Name', 1, 'The Number of The Beast')
# ('Invaders', 1, 'The Number of The Beast')
# ('Run to the Hills', 1, 'The Number of The Beast')
# ('The Number Of The Beast', 1, 'The Number of The Beast')
# ('Sign Of The Cross', 1, 'The X Factor')
# ('Lord Of The Flies', 1, 'The X Factor')
# ('Man On The Edge', 1, 'The X Factor')
# ('Fortunes Of War', 1, 'The X Factor')
# ("Blood On The World's Hands", 1, 'The X Factor')
# ('2 A.M.', 1, 'The X Factor')
# ('The Unbeliever', 1, 'The X Factor')
# ('Futureal', 1, 'Virtual XI')
# ('The Angel And The Gambler', 1, 'Virtual XI')
# ('Lightning Strikes Twice', 1, 'Virtual XI')
# ('The Educated Fool', 1, 'Virtual XI')
# ('Como Estais Amigos', 1, 'Virtual XI')
# ('Night Train', 1, 'Sex Machine')
# ('Out Of Sight', 1, 'Sex Machine')
# ("Papa's Got A Brand New Bag Pt.1", 1, 'Sex Machine')
# ("It's A Man's Man's Man's World", 1, 'Sex Machine')
# ("Say It Loud, I'm Black And I'm Proud Pt.1", 1, 'Sex Machine')
# ('Get Up (I Feel Like Being A) Sex Machine', 1, 'Sex Machine')
# ('Get Up Offa That Thing', 1, 'Sex Machine')
# ("It's Too Funky In Here", 1, 'Sex Machine')
# ('Living In America', 1, 'Sex Machine')
# ("I'm Real", 1, 'Sex Machine')
# ('When You Gonna Learn (Digeridoo)', 1, 'Emergency On Planet Earth')
# ('Too Young To Die', 1, 'Emergency On Planet Earth')
# ('Hooked Up', 1, 'Emergency On Planet Earth')
# ('Blow Your Mind', 1, 'Emergency On Planet Earth')
# ('Planet Home', 1, 'Synkronized')
# ('Black Capricorn Day', 1, 'Synkronized')
# ('Soul Education', 1, 'Synkronized')
# ('Destitute Illusions', 1, 'Synkronized')
# ('Were Do We Go From Here', 1, 'Synkronized')
# ('King For A Day', 1, 'Synkronized')
# ('Deeper Underground', 1, 'Synkronized')
# ('Manifest Destiny', 1, 'The Return Of The Space Cowboy')
# ('Journey To Arnhemland', 1, 'The Return Of The Space Cowboy')
# ('Morning Glory', 1, 'The Return Of The Space Cowboy')
# ('Are You Gonna Be My Girl', 1, 'Get Born')
# ('Rollover D.J.', 1, 'Get Born')
# ('Get What You Need', 1, 'Get Born')
# ('Radio Song', 1, 'Get Born')
# ('Lazy Gun', 1, 'Get Born')
# ('Red House', 1, 'Are You Experienced?')
# ('Can You See Me', 1, 'Are You Experienced?')
# ('May This Be Love', 1, 'Are You Experienced?')
# ('Fire', 1, 'Are You Experienced?')
# ('Hey Joe', 1, 'Are You Experienced?')
# ('Stone Free', 1, 'Are You Experienced?')
# ('The Wind Cries Mary', 1, 'Are You Experienced?')
# ('Highway Chile', 1, 'Are You Experienced?')
# ('Always With Me, Always With You', 1, 'Surfing with the Alien (Remastered)')
# ('Satch Boogie', 1, 'Surfing with the Alien (Remastered)')
# ('Lords of Karma', 1, 'Surfing with the Alien (Remastered)')
# ('Midnight', 1, 'Surfing with the Alien (Remastered)')
# ('Mama Africa', 1, 'Jorge Ben Jor 25 Anos')
# ('Salve Simpatia', 1, 'Jorge Ben Jor 25 Anos')
# ('Os Alquimistas Estão Chegando', 1, 'Jorge Ben Jor 25 Anos')
# ('Charles Anjo 45', 1, 'Jorge Ben Jor 25 Anos')
# ('Santa Clara Clareou', 1, 'Jorge Ben Jor 25 Anos')
# ('Filho Maravilha', 1, 'Jorge Ben Jor 25 Anos')
# ('As Dores do Mundo', 1, 'Jota Quest-1995')
# ('Vou Pra Ai', 1, 'Jota Quest-1995')
# ('Encontrar Alguém', 1, 'Jota Quest-1995')
# ('Dance Enquanto é Tempo', 1, 'Jota Quest-1995')
# ('Sem Sentido', 1, 'Jota Quest-1995')
# ('Onibusfobia', 1, 'Jota Quest-1995')
# ('No Futuro', 1, 'Cafezinho')
# ('Voce Inteira', 1, 'Cafezinho')
# ('Equinocio', 1, 'Cafezinho')
# ('Papelão', 1, 'Cafezinho')
# ('Cafezinho', 1, 'Cafezinho')
# ('Enquanto O Dia Não Vem', 1, 'Cafezinho')
# ("Hot Rockin'", 1, 'Living After Midnight')
# ('Freewheel Burning', 1, 'Living After Midnight')
# ('Metal Meltdown', 1, 'Living After Midnight')
# ('Ram It Down', 1, 'Living After Midnight')
# ('Diamonds And Rust (Live)', 1, 'Living After Midnight')
# ('Tyrant (Live)', 1, 'Living After Midnight')
# ("Comin' Home", 1, 'Unplugged [Live]')
# ...
# ('Lost Survival Guide', 1, 'Lost, Season 3')
# ('Solitary', 1, 'Lost, Season 1')
# ('Stranger In a Strange Land', 1, 'Lost, Season 3')
# ('The 23rd Psalm', 1, 'Lost, Season 2')
# ('Enter 77', 1, 'Lost, Season 3')
# ('Fire + Water', 1, 'Lost, Season 2')
# ('Par Avion', 1, 'Lost, Season 3')
# ('The Long Con', 1, 'Lost, Season 2')
# ('Exposé', 1, 'Lost, Season 3')
# ('Homecoming', 1, 'Lost, Season 1')
# ('Outlaws', 1, 'Lost, Season 1')
# ('The Whole Truth', 1, 'Lost, Season 2')
# ('Catch-22', 1, 'Lost, Season 3')
# ('Dave', 1, 'Lost, Season 2')
# ('Deus Ex Machina', 1, 'Lost, Season 1')
# ('S.O.S.', 1, 'Lost, Season 2')
# ('"?"', 1, 'Lost, Season 2')
# ('Born to Run', 1, 'Lost, Season 1')
# ('Live Together, Die Alone, Pt. 1', 1, 'Lost, Season 2')
# ('Exodus (Part 2) [Season Finale]', 1, 'Lost, Season 1')
# ('Even Better Than The Real Thing', 1, 'Achtung Baby')
# ('One', 1, 'Achtung Baby')
# ('So Cruel', 1, 'Achtung Baby')
# ('The Fly', 1, 'Achtung Baby')
# ('Acrobat', 1, 'Achtung Baby')
# ('Love Is Blindness', 1, 'Achtung Baby')
# ('Walk On', 1, "All That You Can't Leave Behind")
# ('New York', 1, "All That You Can't Leave Behind")
# ('The Three Sunrises', 1, 'B-Sides 1980-1990')
# ('Spanish Eyes', 1, 'B-Sides 1980-1990')
# ('Sweetest Thing', 1, 'B-Sides 1980-1990')
# ('Bass Trap', 1, 'B-Sides 1980-1990')
# ('Dancing Barefoot', 1, 'B-Sides 1980-1990')
# ('Walk To The Water', 1, 'B-Sides 1980-1990')
# ('Trash, Trampoline And The Party Girl', 1, 'B-Sides 1980-1990')
# ('Vertigo', 1, 'How To Dismantle An Atomic Bomb')
# ('Love And Peace Or Else', 1, 'How To Dismantle An Atomic Bomb')
# ('All Because Of You', 1, 'How To Dismantle An Atomic Bomb')
# ('A Man And A Woman', 1, 'How To Dismantle An Atomic Bomb')
# ('Crumbs From Your Table', 1, 'How To Dismantle An Atomic Bomb')
# ('One Step Closer', 1, 'How To Dismantle An Atomic Bomb')
# ('Original Of The Species', 1, 'How To Dismantle An Atomic Bomb')
# ('Yahweh', 1, 'How To Dismantle An Atomic Bomb')
# ('Discotheque', 1, 'Pop')
# ('Do You Feel Loved', 1, 'Pop')
# ('Mofo', 1, 'Pop')
# ('If God Will Send His Angels', 1, 'Pop')
# ('Staring At The Sun', 1, 'Pop')
# ('Last Night On Earth', 1, 'Pop')
# ('The Playboy Mansion', 1, 'Pop')
# ('Wake Up Dead Man', 1, 'Pop')
# ('Desire', 1, 'Rattle And Hum')
# ('Hawkmoon 269', 1, 'Rattle And Hum')
# ("I Still Haven't Found What I'm Looking for", 1, 'Rattle And Hum')
# ('Freedom For My People', 1, 'Rattle And Hum')
# ('Silver And Gold', 1, 'Rattle And Hum')
# ('Love Rescue Me', 1, 'Rattle And Hum')
# ('When Love Comes To Town', 1, 'Rattle And Hum')
# ('Heartland', 1, 'Rattle And Hum')
# ('God Part II', 1, 'Rattle And Hum')
# ('Bullet The Blue Sky', 1, 'Rattle And Hum')
# ('All I Want Is You', 1, 'Rattle And Hum')
# ("New Year's Day", 1, 'The Best Of 1980-1990')
# ('With Or Without You', 1, 'The Best Of 1980-1990')
# ("I Still Haven't Found What I'm Looking For", 1, 'The Best Of 1980-1990')
# ('Bad', 1, 'The Best Of 1980-1990')
# ('The Unforgettable Fire', 1, 'The Best Of 1980-1990')
# ('Desire', 1, 'The Best Of 1980-1990')
# ('When Love Comes To Town', 1, 'The Best Of 1980-1990')
# ('Angel Of Harlem', 1, 'The Best Of 1980-1990')
# ('All I Want Is You', 1, 'The Best Of 1980-1990')
# ('Seconds', 1, 'War')
# ("New Year's Day", 1, 'War')
# ('Like A Song...', 1, 'War')
# ('Drowning Man', 1, 'War')
# ('Surrender', 1, 'War')
# ('Zooropa', 1, 'Zooropa')
# ('Babyface', 1, 'Zooropa')
# ('Numb', 1, 'Zooropa')
# ('Lemon', 1, 'Zooropa')
# ('Stay (Faraway, So Close!)', 1, 'Zooropa')
# ('The First Time', 1, 'Zooropa')
# ('The Wanderer', 1, 'Zooropa')
# ('I Would Do For You', 1, 'UB40 The Best Of - Volume Two [UK]')
# ('Homely Girl', 1, 'UB40 The Best Of - Volume Two [UK]')
# ('Here I Am (Come And Take Me)', 1, 'UB40 The Best Of - Volume Two [UK]')
# ('Wear You To The Ball', 1, 'UB40 The Best Of - Volume Two [UK]')
# ('Higher Ground', 1, 'UB40 The Best Of - Volume Two [UK]')
# ('Bring Me Your Cup', 1, 'UB40 The Best Of - Volume Two [UK]')
# ('Where Have All The Good Times Gone?', 1, 'Diver Down')
# ("Hang 'Em High", 1, 'Diver Down')
# ('Cathedral', 1, 'Diver Down')
# ('Secrets', 1, 'Diver Down')
# ('Dancing In The Street', 1, 'Diver Down')
# ('Little Guitars (Intro)', 1, 'Diver Down')
# ('Little Guitars', 1, 'Diver Down')
# ("Ain't Talkin' 'bout Love", 1, 'The Best Of Van Halen, Vol. I')
# ('Unchained', 1, 'The Best Of Van Halen, Vol. I')
# ('Jump', 1, 'The Best Of Van Halen, Vol. I')
# ('Panama', 1, 'The Best Of Van Halen, Vol. I')
# ('Dreams', 1, 'The Best Of Van Halen, Vol. I')
# ('Right Now', 1, 'The Best Of Van Halen, Vol. I')
# ("Can't Stop Loving You", 1, 'The Best Of Van Halen, Vol. I')
# ('Humans Being', 1, 'The Best Of Van Halen, Vol. I')
# ('You Really Got Me', 1, 'Van Halen')
# ('Atomic Punk', 1, 'Van Halen')
# ('Feel Your Love Tonight', 1, 'Van Halen')
# ('On Fire', 1, 'Van Halen')
# ('Neworld', 1, 'Van Halen III')
# ('One I Want', 1, 'Van Halen III')
# ('Dirty Water Dog', 1, 'Van Halen III')
# ('Primary', 1, 'Van Halen III')
# ('Do It For The Kids', 1, 'Contraband')
# ('Big Machine', 1, 'Contraband')
# ('Fall To Pieces', 1, 'Contraband')
# ('Headspace', 1, 'Contraband')
# ('Slither', 1, 'Contraband')
# ('Dirty Little Thing', 1, 'Contraband')
# ('A Bencao E Outros', 1, 'Vinicius De Moraes')
# ('Tudo Na Mais Santa Paz', 1, 'Vinicius De Moraes')
# ('Samba Pra Endrigo', 1, 'Vinicius De Moraes')
# ('So Por Amor', 1, 'Vinicius De Moraes')
# ('Um Homem Chamado Alfredo', 1, 'Vinicius De Moraes')
# ('Samba Do Jato', 1, 'Vinicius De Moraes')
# ('Still Of The Night', 1, 'Greatest Hits')
# ('Here I Go Again', 1, 'Greatest Hits')
# ('Looking For Love', 1, 'Greatest Hits')
# ("Now You're Gone", 1, 'Greatest Hits')
# ("You're Gonna Break My Hart Again", 1, 'Greatest Hits')
# ('The Deeper The Love', 1, 'Greatest Hits')
# ('Sweet Lady Luck', 1, 'Greatest Hits')
# ('Faixa Amarela', 1, 'Ao Vivo [IMPORT]')
# ('Coração Em Desalinho', 1, 'Ao Vivo [IMPORT]')
# ('Seu Balancê', 1, 'Ao Vivo [IMPORT]')
# ('Feirinha da Pavuna/Luz do Repente/Bagaço da Laranja', 1, 'Ao Vivo [IMPORT]')
# ('Sem Essa de Malandro Agulha', 1, 'Ao Vivo [IMPORT]')
# ('Camarão que Dorme e Onda Leva', 1, 'Ao Vivo [IMPORT]')
# ('Sapopemba e Maxambomba', 1, 'Ao Vivo [IMPORT]')
# ('Samba pras moças', 1, 'Ao Vivo [IMPORT]')
# ('Verdade', 1, 'Ao Vivo [IMPORT]')
# ('The Hard Part', 1, 'Heroes, Season 1')
# ('The Man Behind the Curtain', 1, 'Lost, Season 3')
# ('Diversity Day', 1, 'The Office, Season 1')
# ('The Dundies', 1, 'The Office, Season 2')
# ('Halloween', 1, 'The Office, Season 2')
# ('Email Surveillance', 1, 'The Office, Season 2')
# ('Christmas Party', 1, 'The Office, Season 2')
# ('The Carpet', 1, 'The Office, Season 2')
# ("Michael's Birthday", 1, 'The Office, Season 2')
# ('The Convention', 1, 'The Office, Season 3')
# ('The Coup', 1, 'The Office, Season 3')
# ('The Initiation', 1, 'The Office, Season 3')
# ('Diwali', 1, 'The Office, Season 3')
# ('Branch Closing', 1, 'The Office, Season 3')
# ('The Convict', 1, 'The Office, Season 3')
# ('A Benihana Christmas, Pts. 1 & 2', 1, 'The Office, Season 3')
# ('Back from Vacation', 1, 'The Office, Season 3')
# ("Producer's Cut: The Return", 1, 'The Office, Season 3')
# ('Safety Training', 1, 'The Office, Season 3')
# ('The Job', 1, 'The Office, Season 3')
# ('Through a Looking Glass', 1, 'Lost, Season 3')
# ('Your Time Is Gonna Come', 1, 'Un-Led-Ed')
# ('Battlestar Galactica, Pt. 1', 1, 'Battlestar Galactica (Classic), Season 1')
# ('Battlestar Galactica, Pt. 2', 1, 'Battlestar Galactica (Classic), Season 1')
# ('Lost Planet of the Gods, Pt. 1', 1, 'Battlestar Galactica (Classic), Season 1')
# ('Lost Planet of the Gods, Pt. 2', 1, 'Battlestar Galactica (Classic), Season 1')
# ('The Lost Warrior', 1, 'Battlestar Galactica (Classic), Season 1')
# ('The Long Patrol', 1, 'Battlestar Galactica (Classic), Season 1')
# ('The Gun On Ice Planet Zero, Pt. 1', 1, 'Battlestar Galactica (Classic), Season 1')
# ('The Gun On Ice Planet Zero, Pt. 2', 1, 'Battlestar Galactica (Classic), Season 1')
# ('The Magnificent Warriors', 1, 'Battlestar Galactica (Classic), Season 1')
# ('The Living Legend, Pt. 1', 1, 'Battlestar Galactica (Classic), Season 1')
# ('The Living Legend, Pt. 2', 1, 'Battlestar Galactica (Classic), Season 1')
# ('War of the Gods, Pt. 2', 1, 'Battlestar Galactica (Classic), Season 1')
# ('Greetings from Earth, Pt. 1', 1, 'Battlestar Galactica (Classic), Season 1')
# ('Greetings from Earth, Pt. 2', 1, 'Battlestar Galactica (Classic), Season 1')
# ("Baltar's Escape", 1, 'Battlestar Galactica (Classic), Season 1')
# ('Experiment In Terra', 1, 'Battlestar Galactica (Classic), Season 1')
# ('Take the Celestra', 1, 'Battlestar Galactica (Classic), Season 1')
# ('The Hand of God', 1, 'Battlestar Galactica (Classic), Season 1')
# ('Through the Looking Glass, Pt. 1', 1, 'Lost, Season 3')
# ('Instant Karma', 1, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('#9 Dream', 1, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('Cold Turkey', 1, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('Whatever Gets You Thru the Night', 1, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('Gimme Some Truth', 1, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('Oh, My Love', 1, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('Imagine', 1, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('Jealous Guy', 1, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('Imagine', 1, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('Gimme Some Truth', 1, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('[Just Like] Starting Over', 1, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('God', 1, 'Instant Karma: The Amnesty International Campaign to Save Darfur')
# ('Sympton of the Universe', 1, 'Speak of the Devil')
# ('Fairies Wear Boots', 1, 'Speak of the Devil')
# ('Never Say Die', 1, 'Speak of the Devil')
# ('Sabbath, Bloody Sabbath', 1, 'Speak of the Devil')
# ('Iron Man/Children of the Grave', 1, 'Speak of the Devil')
# ('The Zoo', 1, '20th Century Masters - The Millennium Collection: The Best of Scorpions')
# ('Loving You Sunday Morning', 1, '20th Century Masters - The Millennium Collection: The Best of Scorpions')
# ('Still Loving You', 1, '20th Century Masters - The Millennium Collection: The Best of Scorpions')
# ("I Can't Explain", 1, '20th Century Masters - The Millennium Collection: The Best of Scorpions')
# ('Tease Me Please Me', 1, '20th Century Masters - The Millennium Collection: The Best of Scorpions')
# ('Salutations', 1, 'House of Pain')
# ('Put Your Head Out', 1, 'House of Pain')
# ("Top O' The Morning To Ya", 1, 'House of Pain')
# ('Danny Boy, Danny Boy', 1, 'House of Pain')
# ("Guess Who's Back", 1, 'House of Pain')
# ('Commercial 2', 1, 'House of Pain')
# ('One For The Road', 1, 'House of Pain')
# ('Feel It', 1, 'House of Pain')
# ('Instinto Colectivo', 1, 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro')
# ('Chapa o Coco', 1, 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro')
# ('Um Lugar ao Sol', 1, 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro')
# ('Todo o Carnaval tem seu Fim', 1, 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro')
# ('Armadura', 1, 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro')
# ('Funk de Bamba', 1, 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro')
# ('Chega no Suingue', 1, 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro')
# ('Past, Present, and Future', 1, 'LOST, Season 4')
# ('The Beginning of the End', 1, 'LOST, Season 4')
# ('The Economist', 1, 'LOST, Season 4')
# ('Ji Yeon', 1, 'LOST, Season 4')
# ('Meet Kevin Johnson', 1, 'LOST, Season 4')
# ('Din Din Wo (Little Child)', 1, 'Muso Ko')
# ('Love Comes', 1, 'Every Kind of Light')
# ('Muita Bobeira', 1, 'Duos II')
# ('Something Nice Back Home', 1, 'LOST, Season 4')
# ("There's No Place Like Home, Pt. 3", 1, 'LOST, Season 4')
# ('Say Hello 2 Heaven', 1, 'Temple of the Dog')
# ('Call Me a Dog', 1, 'Temple of the Dog')
# ('Four Walled World', 1, 'Temple of the Dog')
# ('All Night Thing', 1, 'Temple of the Dog')
# ('Safe and Sound', 1, 'Carry On')
# ('Billie Jean', 1, 'Carry On')
# ('Scar On the Sky', 1, 'Carry On')
# ('Disappearing Act', 1, 'Carry On')
# ('Sound of a Gun', 1, 'Revelations')
# ('Until We Fall', 1, 'Revelations')
# ('Shape of Things to Come', 1, 'Revelations')
# ('Moth', 1, 'Revelations')
# ('Show Me How to Live (Live at the Quart Festival)', 1, 'Revelations')
# ('Canon and Gigue in D Major: I. Canon', 1, 'Pachelbel: Canon & Gigue')
# ('Suite for Solo Cello No. 1 in G Major, BWV 1007: I. Prélude', 1, 'Bach: The Cello Suites')
# ('The Messiah: Behold, I Tell You a Mystery... The Trumpet Shall Sound', 1, 'Handel: The Messiah (Highlights)')
# ('Symphony No. 104 in D Major "London": IV. Finale: Spiritoso', 1, 'Haydn: Symphonies 99 - 104')
# ('Die Walküre: The Ride of the Valkyries', 1, 'Wagner: Favourite Overtures')
# ('Requiem, Op.48: 4. Pie Jesu', 1, 'Fauré: Requiem, Ravel: Pavane & Others')
# ('Jupiter, the Bringer of Jollity', 1, 'Holst: The Planets, Op. 32 & Vaughan Williams: Fantasies')
# ('Branch Closing', 1, 'The Office, Season 3')
# ('Concerto No.2 in F Major, BWV1047, I. Allegro', 1, 'Bach: The Brandenburg Concertos')
# ('Concerto for Piano No. 2 in F Minor, Op. 21: II. Larghetto', 1, 'Chopin: Piano Concertos Nos. 1 & 2')
# ('Karelia Suite, Op.11: 2. Ballade (Tempo Di Menuetto)', 1, 'Sibelius: Finlandia')
# ('Piano Sonata No. 14 in C Sharp Minor, Op. 27, No. 2, "Moonlight": I. Adagio sostenuto', 1, 'Beethoven Piano Sonatas: Moonlight & Pastorale')
# ('Fantasia On Greensleeves', 1, 'The World of Classical Favourites')
# ('Concerto for Cello and Orchestra in E minor, Op. 85: I. Adagio - Moderato', 1, 'Elgar: Cello Concerto & Vaughan Williams: Fantasias')
# ('Two Fanfares for Orchestra: II. Short Ride in a Fast Machine', 1, 'Adams, John: The Chairman Dances')
# ("Wellington's Victory or the Battle Symphony, Op.91: 2. Symphony of Triumph", 1, "Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory")
# ('Romeo et Juliette: No. 11 - Danse des Chevaliers', 1, 'Prokofiev: Romeo & Juliet')
# ('Peer Gynt Suite No.1, Op.46: 1. Morning Mood', 1, 'Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélisande')
# ('Symphony No. 41 in C Major, K. 551, "Jupiter": IV. Molto allegro', 1, 'Mozart: Symphonies Nos. 40 & 41')
# ("You Know I'm No Good", 1, 'Back to Black')
# ('Me & Mr. Jones', 1, 'Back to Black')
# ('Just Friends', 1, 'Back to Black')
# ('Back to Black', 1, 'Back to Black')
# ('Tears Dry On Their Own', 1, 'Back to Black')
# ('Wake Up Alone', 1, 'Back to Black')
# ('Some Unholy War', 1, 'Back to Black')
# ('He Can Only Hold Her', 1, 'Back to Black')
# ("You Know I'm No Good (feat. Ghostface Killah)", 1, 'Back to Black')
# ('Rehab (Hot Chip Remix)', 1, 'Back to Black')
# ('Intro / Stronger Than Me', 1, 'Frank')
# ('F**k Me Pumps', 1, 'Frank')
# ('I Heard Love Is Blind', 1, 'Frank')
# ('Take the Box', 1, 'Frank')
# ('Help Yourself', 1, 'Frank')
# ('Amy Amy Amy (Outro)', 1, 'Frank')
# ('Slowness', 1, 'Carried to Dust (Bonus Track Version)')
# ('Prometheus Overture, Op. 43', 1, "Beethoven: Symphony No. 6 'Pastoral' Etc.")
# ('Sonata for Solo Violin: IV: Presto', 1, 'Bartok: Violin & Viola Concertos')
# ("A Midsummer Night's Dream, Op.61 Incidental Music: No.7 Notturno", 1, "Mendelssohn: A Midsummer Night's Dream")
# ('Adios nonino', 1, 'South American Getaway')
# ('Symphony No. 3 Op. 36 for Orchestra and Soprano "Symfonia Piesni Zalosnych" \\ Lento E Largo - Tranquillissimo', 1, 'Górecki: Symphony No. 3')
# ('Act IV, Symphony', 1, 'Purcell: The Fairy Queen')
# ('Symphony No. 2: III. Allegro vivace', 1, 'Weill: The Seven Deadly Sins')
# ('Partita in E Major, BWV 1006A: I. Prelude', 1, 'J.S. Bach: Chaconne, Suite in E Minor, Partita in E Major & Prelude, Fugue and Allegro')
# ('Sing Joyfully', 1, 'English Renaissance')
# ('Metopes, Op. 29: Calypso', 1, 'Szymanowski: Piano Works, Vol. 1')
# ('Symphony No. 2, Op. 16 -  "The Four Temperaments": II. Allegro Comodo e Flemmatico', 1, 'Nielsen: The Six Symphonies')
# ('Étude 1, In C Major - Preludio (Presto) - Liszt', 1, "Liszt - 12 Études D'Execution Transcendante")
# ('Pini Di Roma (Pinien Von Rom) \\ I Pini Della Via Appia', 1, 'Respighi:Pines of Rome')

# %% [markdown]
# 7) Crie um histograma de faixas mais compradas, usando o matplotlib
# https://matplotlib.org/devdocs/api/_as_gen/matplotlib.pyplot.hist.html
